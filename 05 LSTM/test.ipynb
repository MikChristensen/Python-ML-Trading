# %%
# https://youtu.be/tepxdcepTbY
"""
@author: Sreenivas Bhattiprolu
Code tested on Tensorflow: 2.2.0
    Keras: 2.4.3
dataset: https://finance.yahoo.com/quote/GE/history/
Also try S&P: https://finance.yahoo.com/quote/%5EGSPC/history?p=%5EGSPC
https://www.youtube.com/watch?v=tepxdcepTbY
"""

import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM
from tensorflow.keras.layers import Dense, Dropout
import pandas as pd
from matplotlib import pyplot as plt
from sklearn.preprocessing import StandardScaler
import seaborn as sns
#from datetime import datetime
import yfinance as yf
#Read the csv file
df = yf.download('AAPL')
df = df.reset_index()
print(df.head()) #7 columns, including the Date. 

#Separate dates for future plotting
train_dates = pd.to_datetime(df['Date'])
print(train_dates.tail(15)) #Check last few dates. 

#Variables for training
cols = list(df)[1:6]
#Date and volume columns are not used in training. 
print(cols) #['Open', 'High', 'Low', 'Close', 'Adj Close']

#New dataframe with only training data - 5 columns
df_for_training = df[cols].astype(float)

# df_for_plot=df_for_training.tail(5000)
# df_for_plot.plot.line()

#LSTM uses sigmoid and tanh that are sensitive to magnitude so values need to be normalized
# normalize the dataset
scaler = StandardScaler()
scaler = scaler.fit(df_for_training)
df_for_training_scaled = scaler.transform(df_for_training)


#As required for LSTM networks, we require to reshape an input data into n_samples x timesteps x n_features. 
#In this example, the n_features is 5. We will make timesteps = 14 (past days data used for training). 

#Empty lists to be populated using formatted training data
trainX = []
trainY = []

n_future = 1   # Number of days we want to look into the future based on the past days.
n_past = 14  # Number of past days we want to use to predict the future.

#Reformat input data into a shape: (n_samples x timesteps x n_features)
#In my example, my df_for_training_scaled has a shape (12823, 5)
#12823 refers to the number of data points and 5 refers to the columns (multi-variables).
for i in range(n_past, len(df_for_training_scaled) - n_future +1):
    trainX.append(df_for_training_scaled[i - n_past:i, 0:df_for_training.shape[1]])
    trainY.append(df_for_training_scaled[i + n_future - 1:i + n_future, 0])

trainX, trainY = np.array(trainX), np.array(trainY)

print('trainX shape == {}.'.format(trainX.shape))
print('trainY shape == {}.'.format(trainY.shape))

#In my case, trainX has a shape (12809, 14, 5). 
#12809 because we are looking back 14 days (12823 - 14 = 12809). 
#Remember that we cannot look back 14 days until we get to the 15th day. 
#Also, trainY has a shape (12809, 1). Our model only predicts a single value, but 
#it needs multiple variables (5 in my example) to make this prediction. 
#This is why we can only predict a single day after our training, the day after where our data ends.
#To predict more days in future, we need all the 5 variables which we do not have. 
#We need to predict all variables if we want to do that. 

# define the Autoencoder model

#model = Sequential()
#model.add(LSTM(64, activation='relu', input_shape=(trainX.shape[1], trainX.shape[2]), return_sequences=True))
#model.add(LSTM(32, activation='relu', return_sequences=False))
#model.add(Dropout(0.2))
#model.add(Dense(trainY.shape[1]))

model = Sequential()
model.add(LSTM(64, activation='tanh', input_shape=(trainX.shape[1], trainX.shape[2]), return_sequences=True))
model.add(LSTM(32, activation='tanh', return_sequences=False))
model.add(Dropout(0.2))
model.add(Dense(trainY.shape[1]))



model.compile(optimizer='adam', loss='mse')
model.summary()


# fit the model
history = model.fit(trainX, trainY, epochs=50, batch_size=16, validation_split=0.1, verbose=1)

plt.plot(history.history['loss'], label='Training loss')
plt.plot(history.history['val_loss'], label='Validation loss')
plt.legend()

#Predicting...
#Libraries that will help us extract only business days in the US.
#Otherwise our dates would be wrong when we look back (or forward).  
from pandas.tseries.holiday import USFederalHolidayCalendar
from pandas.tseries.offsets import CustomBusinessDay
us_bd = CustomBusinessDay(calendar=USFederalHolidayCalendar())
#Remember that we can only predict one day in future as our model needs 5 variables
#as inputs for prediction. We only have all 5 variables until the last day in our dataset.
n_past = 16
n_days_for_prediction=15  #let us predict past 15 days

predict_period_dates = pd.date_range(list(train_dates)[-n_past], periods=n_days_for_prediction, freq=us_bd).tolist()
print(predict_period_dates)

#Make prediction
prediction = model.predict(trainX[-n_days_for_prediction:]) #shape = (n, 1) where n is the n_days_for_prediction

#Perform inverse transformation to rescale back to original range
#Since we used 5 variables for transform, the inverse expects same dimensions
#Therefore, let us copy our values 5 times and discard them after inverse transform
prediction_copies = np.repeat(prediction, df_for_training.shape[1], axis=-1)
y_pred_future = scaler.inverse_transform(prediction_copies)[:,0]


# Convert timestamp to date
forecast_dates = []
for time_i in predict_period_dates:
    forecast_dates.append(time_i.date())
    
df_forecast = pd.DataFrame({'Date':np.array(forecast_dates), 'Open':y_pred_future})
df_forecast['Date']=pd.to_datetime(df_forecast['Date'])


original = df[['Date', 'Open']]
original['Date']=pd.to_datetime(original['Date'])
original = original.loc[original['Date'] >= '2022-05-02']
# Out:
# 2023-05-01 21:19:09.151382: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-05-01 21:19:09.257140: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-05-01 21:19:09.259633: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-05-01 21:19:10.909578: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# [*********************100%***********************]  1 of 1 completed
#         Date      Open      High       Low     Close  Adj Close     Volume
# 0 1980-12-12  0.128348  0.128906  0.128348  0.128348   0.099722  469033600
# 1 1980-12-15  0.122210  0.122210  0.121652  0.121652   0.094519  175884800
# 2 1980-12-16  0.113281  0.113281  0.112723  0.112723   0.087582  105728000
# 3 1980-12-17  0.115513  0.116071  0.115513  0.115513   0.089749   86441600
# 4 1980-12-18  0.118862  0.119420  0.118862  0.118862   0.092351   73449600
# 10670   2023-04-11
# 10671   2023-04-12
# 10672   2023-04-13
# 10673   2023-04-14
# 10674   2023-04-17
# 10675   2023-04-18
# 10676   2023-04-19
# 10677   2023-04-20
# 10678   2023-04-21
# 10679   2023-04-24
# 10680   2023-04-25
# 10681   2023-04-26
# 10682   2023-04-27
# 10683   2023-04-28
# 10684   2023-05-01
# Name: Date, dtype: datetime64[ns]
# ['Open', 'High', 'Low', 'Close', 'Adj Close']
# trainX shape == (10671, 14, 5).
# trainY shape == (10671, 1).
# 2023-05-01 21:19:16.088202: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-05-01 21:19:16.092255: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-05-01 21:19:16.097635: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-05-01 21:19:16.669124: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-05-01 21:19:16.685370: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-05-01 21:19:16.693000: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 14, 64)            17920
#
#  lstm_1 (LSTM)               (None, 32)                12416
#
#  dropout (Dropout)           (None, 32)                0
#
#  dense (Dense)               (None, 1)                 33
#
# =================================================================
# Total params: 30,369
# Trainable params: 30,369
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 2023-05-01 21:19:17.678068: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-05-01 21:19:17.686003: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-05-01 21:19:17.690680: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-05-01 21:19:18.322781: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-05-01 21:19:18.328747: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-05-01 21:19:18.336102: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-05-01 21:19:21.294928: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-05-01 21:19:21.300757: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-05-01 21:19:21.304890: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-05-01 21:19:21.921468: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-05-01 21:19:21.931956: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-05-01 21:19:21.935322: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 601/601 [==============================] - ETA: 0s - loss: 0.0030
# 2023-05-01 21:19:41.869151: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-05-01 21:19:41.873614: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-05-01 21:19:41.876359: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-05-01 21:19:42.428963: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-05-01 21:19:42.432382: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-05-01 21:19:42.435347: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 601/601 [==============================] - 26s 29ms/step - loss: 0.0030 - val_loss: 1.7048
# Epoch 2/50
# 601/601 [==============================] - 15s 25ms/step - loss: 0.0017 - val_loss: 1.6610
# Epoch 3/50
# 601/601 [==============================] - 16s 26ms/step - loss: 0.0015 - val_loss: 1.3329
# Epoch 4/50
# 601/601 [==============================] - 16s 26ms/step - loss: 0.0012 - val_loss: 0.6322
# Epoch 5/50
# 601/601 [==============================] - 15s 25ms/step - loss: 0.0014 - val_loss: 0.4109
# Epoch 6/50
# 601/601 [==============================] - 16s 27ms/step - loss: 0.0012 - val_loss: 0.5763
# Epoch 7/50
# 601/601 [==============================] - 17s 28ms/step - loss: 0.0012 - val_loss: 0.5620
# Epoch 8/50
# 601/601 [==============================] - 20s 33ms/step - loss: 0.0011 - val_loss: 0.6355
# Epoch 9/50
# 601/601 [==============================] - 22s 37ms/step - loss: 0.0011 - val_loss: 0.7210
# Epoch 10/50
# 601/601 [==============================] - 21s 34ms/step - loss: 0.0011 - val_loss: 0.7112
# Epoch 11/50
# 601/601 [==============================] - 18s 30ms/step - loss: 0.0010 - val_loss: 0.3759
# Epoch 12/50
# 601/601 [==============================] - 18s 30ms/step - loss: 0.0011 - val_loss: 0.3104
# Epoch 13/50
# 601/601 [==============================] - 18s 30ms/step - loss: 0.0010 - val_loss: 0.5598
# Epoch 14/50
# 601/601 [==============================] - 17s 29ms/step - loss: 9.8535e-04 - val_loss: 0.6485
# Epoch 15/50
# 601/601 [==============================] - 19s 31ms/step - loss: 0.0010 - val_loss: 0.8366
# Epoch 16/50
# 601/601 [==============================] - 18s 30ms/step - loss: 0.0010 - val_loss: 0.4276
# Epoch 17/50
# 601/601 [==============================] - 18s 30ms/step - loss: 0.0010 - val_loss: 0.4762
# Epoch 18/50
# 601/601 [==============================] - 19s 31ms/step - loss: 0.0011 - val_loss: 0.4613
# Epoch 19/50
# 601/601 [==============================] - 18s 30ms/step - loss: 9.4000e-04 - val_loss: 0.8461
# Epoch 20/50
# 601/601 [==============================] - 18s 30ms/step - loss: 0.0010 - val_loss: 0.3845
# Epoch 21/50
# 601/601 [==============================] - 18s 31ms/step - loss: 9.9642e-04 - val_loss: 0.5587
# Epoch 22/50
# 601/601 [==============================] - 18s 31ms/step - loss: 9.8173e-04 - val_loss: 0.5488
# Epoch 23/50
# 601/601 [==============================] - 19s 31ms/step - loss: 9.8937e-04 - val_loss: 0.5450
# Epoch 24/50
# 601/601 [==============================] - 18s 30ms/step - loss: 9.2031e-04 - val_loss: 0.5997
# Epoch 25/50
# 601/601 [==============================] - 18s 29ms/step - loss: 0.0010 - val_loss: 0.3726
# Epoch 26/50
# 601/601 [==============================] - 18s 31ms/step - loss: 9.6100e-04 - val_loss: 0.8538
# Epoch 27/50
# 601/601 [==============================] - 18s 31ms/step - loss: 9.7095e-04 - val_loss: 0.3578
# Epoch 28/50
# 601/601 [==============================] - 20s 34ms/step - loss: 0.0010 - val_loss: 0.4744
# Epoch 29/50
# 601/601 [==============================] - 26s 43ms/step - loss: 9.1840e-04 - val_loss: 0.4824
# Epoch 30/50
# 601/601 [==============================] - 26s 43ms/step - loss: 9.1634e-04 - val_loss: 0.6845
# Epoch 31/50
# 601/601 [==============================] - 27s 45ms/step - loss: 9.7999e-04 - val_loss: 0.3779
# Epoch 32/50
# 601/601 [==============================] - 26s 43ms/step - loss: 9.8894e-04 - val_loss: 0.4922
# Epoch 33/50
# 601/601 [==============================] - 27s 44ms/step - loss: 9.6050e-04 - val_loss: 0.7521
# Epoch 34/50
# 601/601 [==============================] - 29s 48ms/step - loss: 9.1865e-04 - val_loss: 0.5213
# Epoch 35/50
# 601/601 [==============================] - 27s 44ms/step - loss: 9.8657e-04 - val_loss: 0.4313
# Epoch 36/50
# 601/601 [==============================] - 27s 46ms/step - loss: 9.4523e-04 - val_loss: 0.4706
# Epoch 37/50
# 601/601 [==============================] - 29s 48ms/step - loss: 9.9159e-04 - val_loss: 0.5811
# Epoch 38/50
# 601/601 [==============================] - 29s 48ms/step - loss: 9.8599e-04 - val_loss: 0.4068
# Epoch 39/50
# 601/601 [==============================] - 28s 46ms/step - loss: 9.3933e-04 - val_loss: 0.4064
# Epoch 40/50
# 601/601 [==============================] - 28s 46ms/step - loss: 8.7636e-04 - val_loss: 0.5002
# Epoch 41/50
# 601/601 [==============================] - 30s 49ms/step - loss: 9.3863e-04 - val_loss: 0.5417
# Epoch 42/50
# 601/601 [==============================] - 29s 49ms/step - loss: 9.3285e-04 - val_loss: 0.3421
# Epoch 43/50
# 601/601 [==============================] - 30s 50ms/step - loss: 9.3924e-04 - val_loss: 0.6374
# Epoch 44/50
# 601/601 [==============================] - 30s 49ms/step - loss: 9.5346e-04 - val_loss: 0.5008
# Epoch 45/50
# 601/601 [==============================] - 27s 44ms/step - loss: 8.6982e-04 - val_loss: 0.6568
# Epoch 46/50
# 601/601 [==============================] - 32s 53ms/step - loss: 9.0370e-04 - val_loss: 0.7400
# Epoch 47/50
# 601/601 [==============================] - 29s 48ms/step - loss: 9.1750e-04 - val_loss: 0.5845
# Epoch 48/50
# 601/601 [==============================] - 23s 39ms/step - loss: 8.9913e-04 - val_loss: 0.6118
# Epoch 49/50
# 601/601 [==============================] - 23s 38ms/step - loss: 8.8419e-04 - val_loss: 0.8249
# Epoch 50/50
# 601/601 [==============================] - 24s 40ms/step - loss: 9.2899e-04 - val_loss: 0.5159
# [Timestamp('2023-04-10 00:00:00', freq='C'), Timestamp('2023-04-11 00:00:00', freq='C'), Timestamp('2023-04-12 00:00:00', freq='C'), Timestamp('2023-04-13 00:00:00', freq='C'), Timestamp('2023-04-14 00:00:00', freq='C'), Timestamp('2023-04-17 00:00:00', freq='C'), Timestamp('2023-04-18 00:00:00', freq='C'), Timestamp('2023-04-19 00:00:00', freq='C'), Timestamp('2023-04-20 00:00:00', freq='C'), Timestamp('2023-04-21 00:00:00', freq='C'), Timestamp('2023-04-24 00:00:00', freq='C'), Timestamp('2023-04-25 00:00:00', freq='C'), Timestamp('2023-04-26 00:00:00', freq='C'), Timestamp('2023-04-27 00:00:00', freq='C'), Timestamp('2023-04-28 00:00:00', freq='C')]
# 2023-05-01 21:38:48.227881: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-05-01 21:38:48.234513: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-05-01 21:38:48.240363: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-05-01 21:38:49.008099: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-05-01 21:38:49.013667: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-05-01 21:38:49.019858: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 1/1 [==============================] - 2s 2s/step
# /home/mik/anaconda3/envs/tensor/lib/python3.8/site-packages/pandas/core/frame.py:3607: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._set_item(key, value)

# %%
sns.lineplot(x= original['Date'], y= original['Open'])
sns.lineplot(x= df_forecast['Date'],y=  df_forecast['Open'])
# Out:
# <Axes: xlabel='Date', ylabel='Open'>
