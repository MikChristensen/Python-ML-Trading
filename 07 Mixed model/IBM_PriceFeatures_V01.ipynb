# %%
# Packages

import numpy as np
import pandas as pd
import tensorflow as tf
import yfinance as yf
from tensorflow.keras.models import *
from tensorflow.keras.layers import *
print('Tensorflow version: {}'.format(tf.__version__))

import matplotlib.pyplot as plt
plt.style.use('seaborn')

import warnings
warnings.filterwarnings('ignore')
# Out:
# Tensorflow version: 2.12.0
# <ipython-input-1-3ad7a3657d10>:12: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn')

# %% [markdown]
# # Parameters

# %% [markdown]
# ## Hyperparameters

# %%
seq_len = 128

# %% [markdown]
# ## Model parameters

# %%
# Data download
symbol = "EURUSD=X"
period ='1mo'
interval ='15m'

# Tensorflow model
epochs = 100

# %% [markdown]
# # Data handling

# %% [markdown]
# ## Load data from YFinance

# %%
# Define function for downloading finance data from yfinance

def get_yfinance_hist(symbol = "EURUSD=X", period ='1mo', interval ='15m' ):
    df_raw = yf.download(symbol,period= period ,interval=interval)
    df_raw["returns"] = np.log(df_raw.Close.div(df_raw.Close.shift(1)))
    df_raw.dropna(how="any",inplace=True)
    df_raw["target"] = np.where(df_raw["returns"].shift(-1) > 0, 1, 0)
    df_raw = df_raw.drop('Volume', axis=1)
    return df_raw


df = get_yfinance_hist(symbol = symbol, period = period, interval= interval )

df.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
#                          Open      High       Low     Close  Adj Close  \
# Datetime
# 2023-07-04 10:30:00  1.090513  1.090513  1.090275  1.090513   1.090513
# 2023-07-04 10:45:00  1.090275  1.090394  1.090156  1.090156   1.090156
# 2023-07-04 11:00:00  1.090156  1.090275  1.090037  1.090156   1.090156
# 2023-07-04 11:15:00  1.090156  1.090394  1.090156  1.090394   1.090394
# 2023-07-04 11:30:00  1.090394  1.090631  1.090394  1.090513   1.090513
#
#                       returns  target
# Datetime
# 2023-07-04 10:30:00  0.000000       0
# 2023-07-04 10:45:00 -0.000327       0
# 2023-07-04 11:00:00  0.000000       1
# 2023-07-04 11:15:00  0.000218       1
# 2023-07-04 11:30:00  0.000109       0

# %%
### To be deleted
'''
IBM_path = 'IBM.csv'

df = pd.read_csv(IBM_path, delimiter=',', usecols=['Date', 'Open', 'High', 'Low', 'Close', 'Volume'])
df_raw["target"] = np.where(df_raw["returns"].shift(-1) > 0, 1, 0)
# Replace 0 to avoid dividing by 0 later on
df['Volume'].replace(to_replace=0, method='ffill', inplace=True)
df.sort_values('Date', inplace=True)
df.head()
'''
# Out:
# '\nIBM_path = \'IBM.csv\'\n\ndf = pd.read_csv(IBM_path, delimiter=\',\', usecols=[\'Date\', \'Open\', \'High\', \'Low\', \'Close\', \'Volume\'])\ndf_raw["target"] = np.where(df_raw["returns"].shift(-1) > 0, 1, 0)\n# Replace 0 to avoid dividing by 0 later on\ndf[\'Volume\'].replace(to_replace=0, method=\'ffill\', inplace=True) \ndf.sort_values(\'Date\', inplace=True)\ndf.head()\n'

# %% [markdown]
# ## Plot daily assets closing prices

# %%
plot_cols = ['Close', 'target', 'Open', 'High', 'Low']
plot_features = df[plot_cols]
plot_features.index = df.index
_ = plot_features.plot(subplots=True)

# %% [markdown]
# ## Calculate normalized percentage change for all columns

# %%
'''Calculate percentage change'''

df['Open'] = df['Open'].pct_change() # Create arithmetic returns column
df['High'] = df['High'].pct_change() # Create arithmetic returns column
df['Low'] = df['Low'].pct_change() # Create arithmetic returns column
df['Close'] = df['Close'].pct_change() # Create arithmetic returns column

df.dropna(how='any', axis=0, inplace=True) # Drop all rows with NaN values

###############################################################################
'''Normalize price columns'''

min_return = min(df[['Open', 'High', 'Low', 'Close']].min(axis=0))
max_return = max(df[['Open', 'High', 'Low', 'Close']].max(axis=0))

# Min-max normalize price columns (0-1 range)
df['Open'] = (df['Open'] - min_return) / (max_return - min_return)
df['High'] = (df['High'] - min_return) / (max_return - min_return)
df['Low'] = (df['Low'] - min_return) / (max_return - min_return)
df['Close'] = (df['Close'] - min_return) / (max_return - min_return)

###############################################################################

# %% [markdown]
# ## Split the df dataframe into test, train and validation dataset

# %%
train_df, val_df, test_df = np.split(df.sample(frac=1, random_state=42),
                       [int(.6*len(df)), int(.8*len(df))])

X_cols = ['Open', 'High', 'Low', 'Close', 'Adj Close', 'returns']
y_cols = 'target'

df_X_train = train_df[X_cols]
df_y_train = train_df[y_cols]

df_X_val = val_df[X_cols]
df_y_val = val_df[y_cols]

df_X_test = test_df[X_cols]
df_y_test = test_df[y_cols]

# %% [markdown]
# ## Print the shapes of the datasets

# %%
# Convert pandas columns into arrays
train_data = train_df.values
val_data = val_df.values
test_data = test_df.values
print('Training data shape: {}'.format(train_data.shape))
print('Validation data shape: {}'.format(val_data.shape))
print('Test data shape: {}'.format(test_data.shape))
# Out:
# Training data shape: (1309, 7)
# Validation data shape: (437, 7)
# Test data shape: (437, 7)

# %% [markdown]
# ## Plot daily changes of close prices and volume

# %%
fig = plt.figure(figsize=(15,10))
st = fig.suptitle("Data Separation", fontsize=20)
st.set_y(0.92)

###############################################################################

ax1 = fig.add_subplot(211)
ax1.plot(np.arange(train_data.shape[0]), train_df['Close'], label='Training data')

ax1.plot(np.arange(train_data.shape[0],
                   train_data.shape[0]+val_data.shape[0]), val_df['Close'], label='Validation data')

ax1.plot(np.arange(train_data.shape[0]+val_data.shape[0],
                   train_data.shape[0]+val_data.shape[0]+test_data.shape[0]), test_df['Close'], label='Test data')
ax1.set_xlabel('Date')
ax1.set_ylabel('Normalized Closing Returns')
# Out:
# Text(0, 0.5, 'Normalized Closing Returns')

# %% [markdown]
# ## Create chunks of training, validation and test data

# %%
# Training data
X_train, y_train = [], []
for i in range(seq_len, len(train_data)):
  X_train.append(df_X_train[i-seq_len:i]) # Chunks of training data with a length of 128 df-rows
  y_train.append(df_y_train[i]) #Value of 4th column (Close Price) of df-row 128+1
X_train, y_train = np.array(X_train), np.array(y_train)

###############################################################################

# Validation data
X_val, y_val = [], []
for i in range(seq_len, len(val_data)):
    X_val.append(df_X_val[i-seq_len:i])
    y_val.append(df_y_val[i])
X_val, y_val = np.array(X_val), np.array(y_val)

###############################################################################

# Test data
X_test, y_test = [], []
for i in range(seq_len, len(test_data)):
    X_test.append(df_X_test[i-seq_len:i])
    y_test.append(df_y_test[i])
X_test, y_test = np.array(X_test), np.array(y_test)

print(X_train.shape, y_train.shape)
print(X_val.shape, y_val.shape)
# Out:
# (1181, 128, 6) (1181,)
# (309, 128, 6) (309,)

# %% [markdown]
# ## 1D Convolution layers for a CNN+LSTM model

# %%
def Inception_A(layer_in, c7):
  branch1x1_1 = Conv1D(c7, kernel_size=1, padding="same", use_bias=False)(layer_in)
  branch1x1 = BatchNormalization()(branch1x1_1)
  branch1x1 = ReLU()(branch1x1)

  branch5x5_1 = Conv1D(c7, kernel_size=1, padding='same', use_bias=False)(layer_in)
  branch5x5 = BatchNormalization()(branch5x5_1)
  branch5x5 = ReLU()(branch5x5)
  branch5x5 = Conv1D(c7, kernel_size=5, padding='same', use_bias=False)(branch5x5)
  branch5x5 = BatchNormalization()(branch5x5)
  branch5x5 = ReLU()(branch5x5)

  branch3x3_1 = Conv1D(c7, kernel_size=1, padding='same', use_bias=False)(layer_in)
  branch3x3 = BatchNormalization()(branch3x3_1)
  branch3x3 = ReLU()(branch3x3)
  branch3x3 = Conv1D(c7, kernel_size=3, padding='same', use_bias=False)(branch3x3)
  branch3x3 = BatchNormalization()(branch3x3)
  branch3x3 = ReLU()(branch3x3)
  branch3x3 = Conv1D(c7, kernel_size=3, padding='same', use_bias=False)(branch3x3)
  branch3x3 = BatchNormalization()(branch3x3)
  branch3x3 = ReLU()(branch3x3)

  branch_pool = AveragePooling1D(pool_size=(3), strides=1, padding='same')(layer_in)
  branch_pool = Conv1D(c7, kernel_size=1, padding='same', use_bias=False)(branch_pool)
  branch_pool = BatchNormalization()(branch_pool)
  branch_pool = ReLU()(branch_pool)
  outputs = Concatenate(axis=-1)([branch1x1, branch5x5, branch3x3, branch_pool])
  return outputs


def Inception_B(layer_in, c7):
  branch3x3 = Conv1D(c7, kernel_size=3, padding="same", strides=2, use_bias=False)(layer_in)
  branch3x3 = BatchNormalization()(branch3x3)
  branch3x3 = ReLU()(branch3x3)

  branch3x3dbl = Conv1D(c7, kernel_size=1, padding="same", use_bias=False)(layer_in)
  branch3x3dbl = BatchNormalization()(branch3x3dbl)
  branch3x3dbl = ReLU()(branch3x3dbl)
  branch3x3dbl = Conv1D(c7, kernel_size=3, padding="same", use_bias=False)(branch3x3dbl)
  branch3x3dbl = BatchNormalization()(branch3x3dbl)
  branch3x3dbl = ReLU()(branch3x3dbl)
  branch3x3dbl = Conv1D(c7, kernel_size=3, padding="same", strides=2, use_bias=False)(branch3x3dbl)
  branch3x3dbl = BatchNormalization()(branch3x3dbl)
  branch3x3dbl = ReLU()(branch3x3dbl)

  branch_pool = MaxPooling1D(pool_size=3, strides=2, padding="same")(layer_in)

  outputs = Concatenate(axis=-1)([branch3x3, branch3x3dbl, branch_pool])
  return outputs


def Inception_C(layer_in, c7):
  branch1x1_1 = Conv1D(c7, kernel_size=1, padding="same", use_bias=False)(layer_in)
  branch1x1 = BatchNormalization()(branch1x1_1)
  branch1x1 = ReLU()(branch1x1)

  branch7x7_1 = Conv1D(c7, kernel_size=1, padding="same", use_bias=False)(layer_in)
  branch7x7 = BatchNormalization()(branch7x7_1)
  branch7x7 = ReLU()(branch7x7)
  branch7x7 = Conv1D(c7, kernel_size=(7), padding="same", use_bias=False)(branch7x7)
  branch7x7 = BatchNormalization()(branch7x7)
  branch7x7 = ReLU()(branch7x7)
  branch7x7 = Conv1D(c7, kernel_size=(1), padding="same", use_bias=False)(branch7x7)
  branch7x7 = BatchNormalization()(branch7x7)
  branch7x7 = ReLU()(branch7x7)

  branch7x7dbl_1 = Conv1D(c7, kernel_size=1, padding="same", use_bias=False)(layer_in)
  branch7x7dbl = BatchNormalization()(branch7x7dbl_1)
  branch7x7dbl = ReLU()(branch7x7dbl)
  branch7x7dbl = Conv1D(c7, kernel_size=(7), padding="same", use_bias=False)(branch7x7dbl)
  branch7x7dbl = BatchNormalization()(branch7x7dbl)
  branch7x7dbl = ReLU()(branch7x7dbl)
  branch7x7dbl = Conv1D(c7, kernel_size=(1), padding="same", use_bias=False)(branch7x7dbl)
  branch7x7dbl = BatchNormalization()(branch7x7dbl)
  branch7x7dbl = ReLU()(branch7x7dbl)
  branch7x7dbl = Conv1D(c7, kernel_size=(7), padding="same", use_bias=False)(branch7x7dbl)
  branch7x7dbl = BatchNormalization()(branch7x7dbl)
  branch7x7dbl = ReLU()(branch7x7dbl)
  branch7x7dbl = Conv1D(c7, kernel_size=(1), padding="same", use_bias=False)(branch7x7dbl)
  branch7x7dbl = BatchNormalization()(branch7x7dbl)
  branch7x7dbl = ReLU()(branch7x7dbl)

  branch_pool = AveragePooling1D(pool_size=3, strides=1, padding='same')(layer_in)
  branch_pool = Conv1D(c7, kernel_size=1, padding='same', use_bias=False)(branch_pool)
  branch_pool = BatchNormalization()(branch_pool)
  branch_pool = ReLU()(branch_pool)

  outputs = Concatenate(axis=-1)([branch1x1, branch7x7, branch7x7dbl, branch_pool])
  return outputs

# %% [markdown]
# # **Testing different model architectures**

# %% [markdown]
# ### Bi-LSTM model

# %%
def create_model():
  in_seq = Input(shape = (seq_len, 6))

  x = Bidirectional(LSTM(128, return_sequences=True))(in_seq)
  x = Bidirectional(LSTM(128, return_sequences=True))(x)
  x = Bidirectional(LSTM(64, return_sequences=True))(x)

  avg_pool = GlobalAveragePooling1D()(x)
  max_pool = GlobalMaxPooling1D()(x)
  conc = concatenate([avg_pool, max_pool])
  conc = Dense(64, activation="relu")(conc)
  out = Dense(1, activation="linear")(conc)

  model = Model(inputs=in_seq, outputs=out)
  model.compile(loss="mse", optimizer="adam", metrics=['mae', 'mape'])
  return model

model = create_model()

#model.summary()
#callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=2)
callback = tf.keras.callbacks.ModelCheckpoint('Bi-LSTM.hdf5', monitor='val_loss', save_best_only=True, verbose=1)

model.fit(X_train, y_train,
              batch_size=2048,
              verbose=2,
              callbacks=[callback],
              epochs=epochs,
              #shuffle=True,
              validation_data=(X_val, y_val),)

#model = tf.keras.models.load_model('/content/Bi-LSTM.hdf5')
model = tf.keras.models.load_model('Bi-LSTM.hdf5')



###############################################################################
'''Calculate predictions and metrics'''

#Calculate predication for training, validation and test data
train_pred = model.predict(X_train)
val_pred = model.predict(X_val)
test_pred = model.predict(X_test)

#Print evaluation metrics for all datasets
train_eval = model.evaluate(X_train, y_train, verbose=0)
val_eval = model.evaluate(X_val, y_val, verbose=0)
test_eval = model.evaluate(X_test, y_test, verbose=0)
print(' ')
print('Evaluation metrics')
print('Training Data - Loss: {:.4f}, MAE: {:.4f}, MAPE: {:.4f}'.format(train_eval[0], train_eval[1], train_eval[2]))
print('Validation Data - Loss: {:.4f}, MAE: {:.4f}, MAPE: {:.4f}'.format(val_eval[0], val_eval[1], val_eval[2]))
print('Test Data - Loss: {:.4f}, MAE: {:.4f}, MAPE: {:.4f}'.format(test_eval[0], test_eval[1], test_eval[2]))

accuracy = tf.keras.metrics.Accuracy()
accuracy.update_state(y_test, test_pred)
result = accuracy.result()



print('Test Data - eval: {:.4f}'.format(result))
###############################################################################
'''Display results'''

fig = plt.figure(figsize=(15,15))
st = fig.suptitle("Bi-LSTM Model", fontsize=22)
st.set_y(1.02)

#Plot training data results
ax11 = fig.add_subplot(311)
ax11.plot(train_data[:, 3], label='IBM Closing Returns')
ax11.plot(train_pred, color='yellow', linewidth=3, label='Predicted IBM Closing Returns')
ax11.set_title("Training Data", fontsize=18)
ax11.set_xlabel('Date')
ax11.set_ylabel('IBM Closing Returns')

#Plot validation data results
ax21 = fig.add_subplot(312)
ax21.plot(val_data[:, 3], label='IBM Closing Returns')
ax21.plot(val_pred, color='yellow', linewidth=3, label='Predicted IBM Closing Returns')
ax21.set_title("Validation Data", fontsize=18)
ax21.set_xlabel('Date')
ax21.set_ylabel('IBM Closing Returns')

#Plot test data results
ax31 = fig.add_subplot(313)
ax31.plot(test_data[:, 3], label='IBM Closing Returns')
ax31.plot(test_pred, color='yellow', linewidth=3, label='Predicted IBM Closing Returns')
ax31.set_title("Test Data", fontsize=18)
ax31.set_xlabel('Date')
ax31.set_ylabel('IBM Closing Returns')

plt.tight_layout()
plt.legend(loc='best')
# Out:
# Epoch 1/100
#
# Epoch 1: val_loss improved from inf to 0.34617, saving model to Bi-LSTM.hdf5
# 1/1 - 21s - loss: 0.3506 - mae: 0.4457 - mape: 60579300.0000 - val_loss: 0.3462 - val_mae: 0.5068 - val_mape: 408526464.0000 - 21s/epoch - 21s/step
# Epoch 2/100
#
# Epoch 2: val_loss improved from 0.34617 to 0.25083, saving model to Bi-LSTM.hdf5
# 1/1 - 1s - loss: 0.3804 - mae: 0.5412 - mape: 454452608.0000 - val_loss: 0.2508 - val_mae: 0.5005 - val_mape: 265187584.0000 - 596ms/epoch - 596ms/step
# Epoch 3/100
#
# Epoch 3: val_loss did not improve from 0.25083
# 1/1 - 0s - loss: 0.2529 - mae: 0.5025 - mape: 295005280.0000 - val_loss: 0.2794 - val_mae: 0.4959 - val_mape: 162053184.0000 - 359ms/epoch - 359ms/step
# Epoch 4/100
#
# Epoch 4: val_loss did not improve from 0.25083
# 1/1 - 0s - loss: 0.2583 - mae: 0.4747 - mape: 180318384.0000 - val_loss: 0.2762 - val_mae: 0.4961 - val_mape: 166920144.0000 - 379ms/epoch - 379ms/step
# Epoch 5/100
#
# Epoch 5: val_loss did not improve from 0.25083
# 1/1 - 0s - loss: 0.2562 - mae: 0.4760 - mape: 185761536.0000 - val_loss: 0.2549 - val_mae: 0.4982 - val_mape: 213870640.0000 - 373ms/epoch - 373ms/step
# Epoch 6/100
#
# Epoch 6: val_loss did not improve from 0.25083
# 1/1 - 0s - loss: 0.2454 - mae: 0.4887 - mape: 237946432.0000 - val_loss: 0.2510 - val_mae: 0.5005 - val_mape: 266979744.0000 - 374ms/epoch - 374ms/step
# Epoch 7/100
#
# Epoch 7: val_loss improved from 0.25083 to 0.24991, saving model to Bi-LSTM.hdf5
# 1/1 - 0s - loss: 0.2535 - mae: 0.5030 - mape: 297019136.0000 - val_loss: 0.2499 - val_mae: 0.4998 - val_mape: 250731664.0000 - 425ms/epoch - 425ms/step
# Epoch 8/100
#
# Epoch 8: val_loss did not improve from 0.24991
# 1/1 - 0s - loss: 0.2487 - mae: 0.4986 - mape: 278939872.0000 - val_loss: 0.2555 - val_mae: 0.4981 - val_mape: 211738672.0000 - 344ms/epoch - 344ms/step
# Epoch 9/100
#
# Epoch 9: val_loss did not improve from 0.24991
# 1/1 - 0s - loss: 0.2455 - mae: 0.4881 - mape: 235524512.0000 - val_loss: 0.2654 - val_mae: 0.4969 - val_mape: 186133488.0000 - 378ms/epoch - 378ms/step
# Epoch 10/100
#
# Epoch 10: val_loss did not improve from 0.24991
# 1/1 - 0s - loss: 0.2497 - mae: 0.4812 - mape: 207018512.0000 - val_loss: 0.2623 - val_mae: 0.4972 - val_mape: 192978736.0000 - 378ms/epoch - 378ms/step
# Epoch 11/100
#
# Epoch 11: val_loss did not improve from 0.24991
# 1/1 - 0s - loss: 0.2481 - mae: 0.4830 - mape: 214625920.0000 - val_loss: 0.2534 - val_mae: 0.4984 - val_mape: 219668576.0000 - 347ms/epoch - 347ms/step
# Epoch 12/100
#
# Epoch 12: val_loss did not improve from 0.24991
# 1/1 - 0s - loss: 0.2452 - mae: 0.4903 - mape: 244342592.0000 - val_loss: 0.2500 - val_mae: 0.4995 - val_mape: 244768816.0000 - 359ms/epoch - 359ms/step
# Epoch 13/100
#
# Epoch 13: val_loss did not improve from 0.24991
# 1/1 - 0s - loss: 0.2475 - mae: 0.4970 - mape: 272240608.0000 - val_loss: 0.2499 - val_mae: 0.4997 - val_mape: 247949616.0000 - 377ms/epoch - 377ms/step
# Epoch 14/100
#
# Epoch 14: val_loss did not improve from 0.24991
# 1/1 - 0s - loss: 0.2481 - mae: 0.4979 - mape: 275786592.0000 - val_loss: 0.2514 - val_mae: 0.4989 - val_mape: 230300656.0000 - 351ms/epoch - 351ms/step
# Epoch 15/100
#
# Epoch 15: val_loss did not improve from 0.24991
# 1/1 - 0s - loss: 0.2456 - mae: 0.4931 - mape: 256162112.0000 - val_loss: 0.2566 - val_mae: 0.4979 - val_mape: 208040944.0000 - 377ms/epoch - 377ms/step
# Epoch 16/100
#
# Epoch 16: val_loss did not improve from 0.24991
# 1/1 - 0s - loss: 0.2458 - mae: 0.4871 - mape: 231390240.0000 - val_loss: 0.2603 - val_mae: 0.4975 - val_mape: 197745152.0000 - 378ms/epoch - 378ms/step
# Epoch 17/100
#
# Epoch 17: val_loss did not improve from 0.24991
# 1/1 - 0s - loss: 0.2472 - mae: 0.4843 - mape: 219937200.0000 - val_loss: 0.2572 - val_mae: 0.4978 - val_mape: 206018224.0000 - 375ms/epoch - 375ms/step
# Epoch 18/100
#
# Epoch 18: val_loss did not improve from 0.24991
# 1/1 - 0s - loss: 0.2460 - mae: 0.4866 - mape: 229129936.0000 - val_loss: 0.2523 - val_mae: 0.4986 - val_mape: 224676688.0000 - 351ms/epoch - 351ms/step
# Epoch 19/100
#
# Epoch 19: val_loss did not improve from 0.24991
# 1/1 - 0s - loss: 0.2453 - mae: 0.4916 - mape: 249892704.0000 - val_loss: 0.2504 - val_mae: 0.4992 - val_mape: 238059088.0000 - 382ms/epoch - 382ms/step
# Epoch 20/100
#
# Epoch 20: val_loss did not improve from 0.24991
# 1/1 - 0s - loss: 0.2464 - mae: 0.4952 - mape: 264782224.0000 - val_loss: 0.2508 - val_mae: 0.4991 - val_mape: 234889376.0000 - 359ms/epoch - 359ms/step
# Epoch 21/100
#
# Epoch 21: val_loss did not improve from 0.24991
# 1/1 - 0s - loss: 0.2460 - mae: 0.4944 - mape: 261257760.0000 - val_loss: 0.2532 - val_mae: 0.4985 - val_mape: 220474432.0000 - 358ms/epoch - 358ms/step
# Epoch 22/100
#
# Epoch 22: val_loss did not improve from 0.24991
# 1/1 - 0s - loss: 0.2452 - mae: 0.4905 - mape: 245224784.0000 - val_loss: 0.2567 - val_mae: 0.4979 - val_mape: 207642992.0000 - 350ms/epoch - 350ms/step
# Epoch 23/100
#
# Epoch 23: val_loss did not improve from 0.24991
# 1/1 - 0s - loss: 0.2459 - mae: 0.4870 - mape: 230953712.0000 - val_loss: 0.2572 - val_mae: 0.4978 - val_mape: 206183024.0000 - 354ms/epoch - 354ms/step
# Epoch 24/100
#
# Epoch 24: val_loss did not improve from 0.24991
# 1/1 - 0s - loss: 0.2460 - mae: 0.4866 - mape: 229330672.0000 - val_loss: 0.2543 - val_mae: 0.4982 - val_mape: 215752864.0000 - 347ms/epoch - 347ms/step
# Epoch 25/100
#
# Epoch 25: val_loss did not improve from 0.24991
# 1/1 - 0s - loss: 0.2453 - mae: 0.4892 - mape: 239983184.0000 - val_loss: 0.2517 - val_mae: 0.4988 - val_mape: 228017296.0000 - 354ms/epoch - 354ms/step
# Epoch 26/100
#
# Epoch 26: val_loss did not improve from 0.24991
# 1/1 - 0s - loss: 0.2455 - mae: 0.4925 - mape: 253647232.0000 - val_loss: 0.2510 - val_mae: 0.4990 - val_mape: 232787584.0000 - 353ms/epoch - 353ms/step
# Epoch 27/100
#
# Epoch 27: val_loss did not improve from 0.24991
# 1/1 - 0s - loss: 0.2458 - mae: 0.4938 - mape: 258957312.0000 - val_loss: 0.2519 - val_mae: 0.4987 - val_mape: 226776640.0000 - 349ms/epoch - 349ms/step
# Epoch 28/100
#
# Epoch 28: val_loss did not improve from 0.24991
# 1/1 - 0s - loss: 0.2454 - mae: 0.4922 - mape: 252274176.0000 - val_loss: 0.2542 - val_mae: 0.4983 - val_mape: 216144368.0000 - 350ms/epoch - 350ms/step
# Epoch 29/100
#
# Epoch 29: val_loss did not improve from 0.24991
# 1/1 - 0s - loss: 0.2453 - mae: 0.4893 - mape: 240449968.0000 - val_loss: 0.2559 - val_mae: 0.4980 - val_mape: 210109680.0000 - 357ms/epoch - 357ms/step
# Epoch 30/100
#
# Epoch 30: val_loss did not improve from 0.24991
# 1/1 - 0s - loss: 0.2456 - mae: 0.4877 - mape: 233740000.0000 - val_loss: 0.2551 - val_mae: 0.4981 - val_mape: 213119216.0000 - 355ms/epoch - 355ms/step
# Epoch 31/100
#
# Epoch 31: val_loss did not improve from 0.24991
# 1/1 - 0s - loss: 0.2454 - mae: 0.4885 - mape: 237089408.0000 - val_loss: 0.2529 - val_mae: 0.4985 - val_mape: 221885504.0000 - 387ms/epoch - 387ms/step
# Epoch 32/100
#
# Epoch 32: val_loss did not improve from 0.24991
# 1/1 - 0s - loss: 0.2452 - mae: 0.4909 - mape: 246841600.0000 - val_loss: 0.2516 - val_mae: 0.4988 - val_mape: 228676976.0000 - 385ms/epoch - 385ms/step
# Epoch 33/100
#
# Epoch 33: val_loss did not improve from 0.24991
# 1/1 - 0s - loss: 0.2455 - mae: 0.4927 - mape: 254397232.0000 - val_loss: 0.2517 - val_mae: 0.4988 - val_mape: 227806848.0000 - 372ms/epoch - 372ms/step
# Epoch 34/100
#
# Epoch 34: val_loss did not improve from 0.24991
# 1/1 - 0s - loss: 0.2454 - mae: 0.4925 - mape: 253430240.0000 - val_loss: 0.2531 - val_mae: 0.4985 - val_mape: 220752720.0000 - 369ms/epoch - 369ms/step
# Epoch 35/100
#
# Epoch 35: val_loss did not improve from 0.24991
# 1/1 - 0s - loss: 0.2452 - mae: 0.4906 - mape: 245582624.0000 - val_loss: 0.2548 - val_mae: 0.4982 - val_mape: 214130176.0000 - 379ms/epoch - 379ms/step
# Epoch 36/100
#
# Epoch 36: val_loss did not improve from 0.24991
# 1/1 - 0s - loss: 0.2454 - mae: 0.4888 - mape: 238213456.0000 - val_loss: 0.2549 - val_mae: 0.4981 - val_mape: 213514304.0000 - 373ms/epoch - 373ms/step
# Epoch 37/100
#
# Epoch 37: val_loss did not improve from 0.24991
# 1/1 - 0s - loss: 0.2454 - mae: 0.4886 - mape: 237523184.0000 - val_loss: 0.2536 - val_mae: 0.4984 - val_mape: 218872048.0000 - 354ms/epoch - 354ms/step
# Epoch 38/100
#
# Epoch 38: val_loss did not improve from 0.24991
# 1/1 - 0s - loss: 0.2452 - mae: 0.4900 - mape: 243482688.0000 - val_loss: 0.2522 - val_mae: 0.4987 - val_mape: 225118144.0000 - 358ms/epoch - 358ms/step
# Epoch 39/100
#
# Epoch 39: val_loss did not improve from 0.24991
# 1/1 - 0s - loss: 0.2453 - mae: 0.4917 - mape: 250430592.0000 - val_loss: 0.2519 - val_mae: 0.4987 - val_mape: 226681552.0000 - 354ms/epoch - 354ms/step
# Epoch 40/100
#
# Epoch 40: val_loss did not improve from 0.24991
# 1/1 - 0s - loss: 0.2454 - mae: 0.4921 - mape: 252169488.0000 - val_loss: 0.2527 - val_mae: 0.4985 - val_mape: 222567712.0000 - 377ms/epoch - 377ms/step
# Epoch 41/100
#
# Epoch 41: val_loss did not improve from 0.24991
# 1/1 - 0s - loss: 0.2452 - mae: 0.4910 - mape: 247593376.0000 - val_loss: 0.2540 - val_mae: 0.4983 - val_mape: 216970416.0000 - 349ms/epoch - 349ms/step
# Epoch 42/100
#
# Epoch 42: val_loss did not improve from 0.24991
# 1/1 - 0s - loss: 0.2453 - mae: 0.4895 - mape: 241367808.0000 - val_loss: 0.2545 - val_mae: 0.4982 - val_mape: 214984928.0000 - 354ms/epoch - 354ms/step
# Epoch 43/100
#
# Epoch 43: val_loss did not improve from 0.24991
# 1/1 - 0s - loss: 0.2453 - mae: 0.4890 - mape: 239159504.0000 - val_loss: 0.2538 - val_mae: 0.4983 - val_mape: 218041936.0000 - 358ms/epoch - 358ms/step
# Epoch 44/100
#
# Epoch 44: val_loss did not improve from 0.24991
# 1/1 - 0s - loss: 0.2452 - mae: 0.4898 - mape: 242559360.0000 - val_loss: 0.2526 - val_mae: 0.4986 - val_mape: 222993312.0000 - 381ms/epoch - 381ms/step
# Epoch 45/100
#
# Epoch 45: val_loss did not improve from 0.24991
# 1/1 - 0s - loss: 0.2453 - mae: 0.4912 - mape: 248066048.0000 - val_loss: 0.2522 - val_mae: 0.4987 - val_mape: 225159776.0000 - 355ms/epoch - 355ms/step
# Epoch 46/100
#
# Epoch 46: val_loss did not improve from 0.24991
# 1/1 - 0s - loss: 0.2453 - mae: 0.4917 - mape: 250475424.0000 - val_loss: 0.2527 - val_mae: 0.4986 - val_mape: 222758848.0000 - 351ms/epoch - 351ms/step
# Epoch 47/100
#
# Epoch 47: val_loss did not improve from 0.24991
# 1/1 - 0s - loss: 0.2452 - mae: 0.4911 - mape: 247804928.0000 - val_loss: 0.2537 - val_mae: 0.4984 - val_mape: 218438912.0000 - 380ms/epoch - 380ms/step
# Epoch 48/100
#
# Epoch 48: val_loss did not improve from 0.24991
# 1/1 - 0s - loss: 0.2452 - mae: 0.4899 - mape: 243000192.0000 - val_loss: 0.2542 - val_mae: 0.4983 - val_mape: 216392128.0000 - 384ms/epoch - 384ms/step
# Epoch 49/100
#
# Epoch 49: val_loss did not improve from 0.24991
# 1/1 - 0s - loss: 0.2453 - mae: 0.4894 - mape: 240723600.0000 - val_loss: 0.2537 - val_mae: 0.4984 - val_mape: 218320816.0000 - 373ms/epoch - 373ms/step
# Epoch 50/100
#
# Epoch 50: val_loss did not improve from 0.24991
# 1/1 - 0s - loss: 0.2452 - mae: 0.4899 - mape: 242868432.0000 - val_loss: 0.2528 - val_mae: 0.4985 - val_mape: 222081536.0000 - 350ms/epoch - 350ms/step
# Epoch 51/100
#
# Epoch 51: val_loss did not improve from 0.24991
# 1/1 - 0s - loss: 0.2452 - mae: 0.4909 - mape: 247050768.0000 - val_loss: 0.2525 - val_mae: 0.4986 - val_mape: 223933408.0000 - 357ms/epoch - 357ms/step
# Epoch 52/100
#
# Epoch 52: val_loss did not improve from 0.24991
# 1/1 - 0s - loss: 0.2453 - mae: 0.4914 - mape: 249109936.0000 - val_loss: 0.2528 - val_mae: 0.4985 - val_mape: 222237392.0000 - 358ms/epoch - 358ms/step
# Epoch 53/100
#
# Epoch 53: val_loss did not improve from 0.24991
# 1/1 - 0s - loss: 0.2452 - mae: 0.4909 - mape: 247223040.0000 - val_loss: 0.2535 - val_mae: 0.4984 - val_mape: 218960144.0000 - 355ms/epoch - 355ms/step
# Epoch 54/100
#
# Epoch 54: val_loss did not improve from 0.24991
# 1/1 - 0s - loss: 0.2452 - mae: 0.4901 - mape: 243577648.0000 - val_loss: 0.2539 - val_mae: 0.4983 - val_mape: 217440752.0000 - 354ms/epoch - 354ms/step
# Epoch 55/100
#
# Epoch 55: val_loss did not improve from 0.24991
# 1/1 - 0s - loss: 0.2453 - mae: 0.4897 - mape: 241887216.0000 - val_loss: 0.2535 - val_mae: 0.4984 - val_mape: 219008592.0000 - 355ms/epoch - 355ms/step
# Epoch 56/100
#
# Epoch 56: val_loss did not improve from 0.24991
# 1/1 - 0s - loss: 0.2452 - mae: 0.4901 - mape: 243630272.0000 - val_loss: 0.2529 - val_mae: 0.4985 - val_mape: 221859024.0000 - 380ms/epoch - 380ms/step
# Epoch 57/100
#
# Epoch 57: val_loss did not improve from 0.24991
# 1/1 - 0s - loss: 0.2452 - mae: 0.4908 - mape: 246800000.0000 - val_loss: 0.2526 - val_mae: 0.4986 - val_mape: 223031888.0000 - 354ms/epoch - 354ms/step
# Epoch 58/100
#
# Epoch 58: val_loss did not improve from 0.24991
# 1/1 - 0s - loss: 0.2452 - mae: 0.4912 - mape: 248104096.0000 - val_loss: 0.2530 - val_mae: 0.4985 - val_mape: 221479328.0000 - 353ms/epoch - 353ms/step
# Epoch 59/100
#
# Epoch 59: val_loss did not improve from 0.24991
# 1/1 - 0s - loss: 0.2452 - mae: 0.4907 - mape: 246376912.0000 - val_loss: 0.2535 - val_mae: 0.4984 - val_mape: 219025840.0000 - 358ms/epoch - 358ms/step
# Epoch 60/100
#
# Epoch 60: val_loss did not improve from 0.24991
# 1/1 - 0s - loss: 0.2452 - mae: 0.4901 - mape: 243647584.0000 - val_loss: 0.2537 - val_mae: 0.4984 - val_mape: 218254608.0000 - 353ms/epoch - 353ms/step
# Epoch 61/100
#
# Epoch 61: val_loss did not improve from 0.24991
# 1/1 - 0s - loss: 0.2452 - mae: 0.4899 - mape: 242789376.0000 - val_loss: 0.2533 - val_mae: 0.4984 - val_mape: 219809008.0000 - 358ms/epoch - 358ms/step
# Epoch 62/100
#
# Epoch 62: val_loss did not improve from 0.24991
# 1/1 - 0s - loss: 0.2452 - mae: 0.4903 - mape: 244517984.0000 - val_loss: 0.2529 - val_mae: 0.4985 - val_mape: 221885232.0000 - 347ms/epoch - 347ms/step
# Epoch 63/100
#
# Epoch 63: val_loss did not improve from 0.24991
# 1/1 - 0s - loss: 0.2452 - mae: 0.4908 - mape: 246827088.0000 - val_loss: 0.2528 - val_mae: 0.4985 - val_mape: 222259840.0000 - 349ms/epoch - 349ms/step
# Epoch 64/100
#
# Epoch 64: val_loss did not improve from 0.24991
# 1/1 - 0s - loss: 0.2452 - mae: 0.4909 - mape: 247243488.0000 - val_loss: 0.2531 - val_mae: 0.4985 - val_mape: 220682224.0000 - 363ms/epoch - 363ms/step
# Epoch 65/100
#
# Epoch 65: val_loss did not improve from 0.24991
# 1/1 - 0s - loss: 0.2452 - mae: 0.4905 - mape: 245488368.0000 - val_loss: 0.2535 - val_mae: 0.4984 - val_mape: 219004112.0000 - 398ms/epoch - 398ms/step
# Epoch 66/100
#
# Epoch 66: val_loss did not improve from 0.24991
# 1/1 - 0s - loss: 0.2452 - mae: 0.4901 - mape: 243621456.0000 - val_loss: 0.2535 - val_mae: 0.4984 - val_mape: 219023088.0000 - 401ms/epoch - 401ms/step
# Epoch 67/100
#
# Epoch 67: val_loss did not improve from 0.24991
# 1/1 - 0s - loss: 0.2452 - mae: 0.4901 - mape: 243642240.0000 - val_loss: 0.2532 - val_mae: 0.4985 - val_mape: 220571104.0000 - 402ms/epoch - 402ms/step
# Epoch 68/100
#
# Epoch 68: val_loss did not improve from 0.24991
# 1/1 - 0s - loss: 0.2452 - mae: 0.4905 - mape: 245363872.0000 - val_loss: 0.2529 - val_mae: 0.4985 - val_mape: 221839952.0000 - 400ms/epoch - 400ms/step
# Epoch 69/100
#
# Epoch 69: val_loss did not improve from 0.24991
# 1/1 - 0s - loss: 0.2452 - mae: 0.4908 - mape: 246775024.0000 - val_loss: 0.2530 - val_mae: 0.4985 - val_mape: 221461600.0000 - 399ms/epoch - 399ms/step
# Epoch 70/100
#
# Epoch 70: val_loss did not improve from 0.24991
# 1/1 - 0s - loss: 0.2452 - mae: 0.4907 - mape: 246353824.0000 - val_loss: 0.2533 - val_mae: 0.4984 - val_mape: 219999136.0000 - 365ms/epoch - 365ms/step
# Epoch 71/100
#
# Epoch 71: val_loss did not improve from 0.24991
# 1/1 - 0s - loss: 0.2452 - mae: 0.4903 - mape: 244726720.0000 - val_loss: 0.2535 - val_mae: 0.4984 - val_mape: 219172304.0000 - 380ms/epoch - 380ms/step
# Epoch 72/100
#
# Epoch 72: val_loss did not improve from 0.24991
# 1/1 - 0s - loss: 0.2452 - mae: 0.4901 - mape: 243806800.0000 - val_loss: 0.2533 - val_mae: 0.4984 - val_mape: 219843824.0000 - 379ms/epoch - 379ms/step
# Epoch 73/100
#
# Epoch 73: val_loss did not improve from 0.24991
# 1/1 - 0s - loss: 0.2452 - mae: 0.4903 - mape: 244553584.0000 - val_loss: 0.2530 - val_mae: 0.4985 - val_mape: 221131680.0000 - 356ms/epoch - 356ms/step
# Epoch 74/100
#
# Epoch 74: val_loss did not improve from 0.24991
# 1/1 - 0s - loss: 0.2452 - mae: 0.4906 - mape: 245986096.0000 - val_loss: 0.2530 - val_mae: 0.4985 - val_mape: 221524464.0000 - 379ms/epoch - 379ms/step
# Epoch 75/100
#
# Epoch 75: val_loss did not improve from 0.24991
# 1/1 - 0s - loss: 0.2452 - mae: 0.4907 - mape: 246422992.0000 - val_loss: 0.2532 - val_mae: 0.4985 - val_mape: 220650480.0000 - 360ms/epoch - 360ms/step
# Epoch 76/100
#
# Epoch 76: val_loss did not improve from 0.24991
# 1/1 - 0s - loss: 0.2452 - mae: 0.4905 - mape: 245450944.0000 - val_loss: 0.2534 - val_mae: 0.4984 - val_mape: 219626480.0000 - 351ms/epoch - 351ms/step
# Epoch 77/100
#
# Epoch 77: val_loss did not improve from 0.24991
# 1/1 - 0s - loss: 0.2452 - mae: 0.4902 - mape: 244312080.0000 - val_loss: 0.2534 - val_mae: 0.4984 - val_mape: 219646144.0000 - 352ms/epoch - 352ms/step
# Epoch 78/100
#
# Epoch 78: val_loss did not improve from 0.24991
# 1/1 - 0s - loss: 0.2452 - mae: 0.4902 - mape: 244334128.0000 - val_loss: 0.2532 - val_mae: 0.4985 - val_mape: 220593360.0000 - 355ms/epoch - 355ms/step
# Epoch 79/100
#
# Epoch 79: val_loss did not improve from 0.24991
# 1/1 - 0s - loss: 0.2452 - mae: 0.4905 - mape: 245387952.0000 - val_loss: 0.2530 - val_mae: 0.4985 - val_mape: 221280048.0000 - 354ms/epoch - 354ms/step
# Epoch 80/100
#
# Epoch 80: val_loss did not improve from 0.24991
# 1/1 - 0s - loss: 0.2452 - mae: 0.4907 - mape: 246152048.0000 - val_loss: 0.2531 - val_mae: 0.4985 - val_mape: 220916688.0000 - 355ms/epoch - 355ms/step
# Epoch 81/100
#
# Epoch 81: val_loss did not improve from 0.24991
# 1/1 - 0s - loss: 0.2452 - mae: 0.4906 - mape: 245748256.0000 - val_loss: 0.2533 - val_mae: 0.4984 - val_mape: 220031952.0000 - 355ms/epoch - 355ms/step
# Epoch 82/100
#
# Epoch 82: val_loss did not improve from 0.24991
# 1/1 - 0s - loss: 0.2452 - mae: 0.4903 - mape: 244764384.0000 - val_loss: 0.2534 - val_mae: 0.4984 - val_mape: 219724688.0000 - 355ms/epoch - 355ms/step
# Epoch 83/100
#
# Epoch 83: val_loss did not improve from 0.24991
# 1/1 - 0s - loss: 0.2452 - mae: 0.4903 - mape: 244422832.0000 - val_loss: 0.2532 - val_mae: 0.4984 - val_mape: 220312048.0000 - 355ms/epoch - 355ms/step
# Epoch 84/100
#
# Epoch 84: val_loss did not improve from 0.24991
# 1/1 - 0s - loss: 0.2452 - mae: 0.4904 - mape: 245076368.0000 - val_loss: 0.2531 - val_mae: 0.4985 - val_mape: 221006032.0000 - 356ms/epoch - 356ms/step
# Epoch 85/100
#
# Epoch 85: val_loss did not improve from 0.24991
# 1/1 - 0s - loss: 0.2452 - mae: 0.4906 - mape: 245848368.0000 - val_loss: 0.2531 - val_mae: 0.4985 - val_mape: 220952496.0000 - 384ms/epoch - 384ms/step
# Epoch 86/100
#
# Epoch 86: val_loss did not improve from 0.24991
# 1/1 - 0s - loss: 0.2452 - mae: 0.4906 - mape: 245788848.0000 - val_loss: 0.2532 - val_mae: 0.4984 - val_mape: 220282528.0000 - 356ms/epoch - 356ms/step
# Epoch 87/100
#
# Epoch 87: val_loss did not improve from 0.24991
# 1/1 - 0s - loss: 0.2452 - mae: 0.4904 - mape: 245043632.0000 - val_loss: 0.2533 - val_mae: 0.4984 - val_mape: 219875456.0000 - 351ms/epoch - 351ms/step
# Epoch 88/100
#
# Epoch 88: val_loss did not improve from 0.24991
# 1/1 - 0s - loss: 0.2452 - mae: 0.4903 - mape: 244590624.0000 - val_loss: 0.2533 - val_mae: 0.4984 - val_mape: 220209920.0000 - 353ms/epoch - 353ms/step
# Epoch 89/100
#
# Epoch 89: val_loss did not improve from 0.24991
# 1/1 - 0s - loss: 0.2452 - mae: 0.4904 - mape: 244962416.0000 - val_loss: 0.2531 - val_mae: 0.4985 - val_mape: 220805408.0000 - 354ms/epoch - 354ms/step
# Epoch 90/100
#
# Epoch 90: val_loss did not improve from 0.24991
# 1/1 - 0s - loss: 0.2452 - mae: 0.4905 - mape: 245624464.0000 - val_loss: 0.2531 - val_mae: 0.4985 - val_mape: 220892336.0000 - 356ms/epoch - 356ms/step
# Epoch 91/100
#
# Epoch 91: val_loss did not improve from 0.24991
# 1/1 - 0s - loss: 0.2452 - mae: 0.4906 - mape: 245720688.0000 - val_loss: 0.2532 - val_mae: 0.4984 - val_mape: 220407168.0000 - 352ms/epoch - 352ms/step
# Epoch 92/100
#
# Epoch 92: val_loss did not improve from 0.24991
# 1/1 - 0s - loss: 0.2452 - mae: 0.4904 - mape: 245180448.0000 - val_loss: 0.2533 - val_mae: 0.4984 - val_mape: 220016384.0000 - 355ms/epoch - 355ms/step
# Epoch 93/100
#
# Epoch 93: val_loss did not improve from 0.24991
# 1/1 - 0s - loss: 0.2452 - mae: 0.4903 - mape: 244745104.0000 - val_loss: 0.2533 - val_mae: 0.4984 - val_mape: 220208880.0000 - 381ms/epoch - 381ms/step
# Epoch 94/100
#
# Epoch 94: val_loss did not improve from 0.24991
# 1/1 - 0s - loss: 0.2452 - mae: 0.4904 - mape: 244958592.0000 - val_loss: 0.2531 - val_mae: 0.4985 - val_mape: 220686032.0000 - 353ms/epoch - 353ms/step
# Epoch 95/100
#
# Epoch 95: val_loss did not improve from 0.24991
# 1/1 - 0s - loss: 0.2452 - mae: 0.4905 - mape: 245488704.0000 - val_loss: 0.2531 - val_mae: 0.4985 - val_mape: 220806656.0000 - 355ms/epoch - 355ms/step
# Epoch 96/100
#
# Epoch 96: val_loss did not improve from 0.24991
# 1/1 - 0s - loss: 0.2452 - mae: 0.4905 - mape: 245622208.0000 - val_loss: 0.2532 - val_mae: 0.4985 - val_mape: 220447952.0000 - 376ms/epoch - 376ms/step
# Epoch 97/100
#
# Epoch 97: val_loss did not improve from 0.24991
# 1/1 - 0s - loss: 0.2452 - mae: 0.4904 - mape: 245222592.0000 - val_loss: 0.2533 - val_mae: 0.4984 - val_mape: 220123248.0000 - 393ms/epoch - 393ms/step
# Epoch 98/100
#
# Epoch 98: val_loss did not improve from 0.24991
# 1/1 - 0s - loss: 0.2452 - mae: 0.4904 - mape: 244860864.0000 - val_loss: 0.2532 - val_mae: 0.4984 - val_mape: 220253824.0000 - 399ms/epoch - 399ms/step
# Epoch 99/100
#
# Epoch 99: val_loss did not improve from 0.24991
# 1/1 - 0s - loss: 0.2452 - mae: 0.4904 - mape: 245005664.0000 - val_loss: 0.2532 - val_mae: 0.4985 - val_mape: 220625680.0000 - 380ms/epoch - 380ms/step
# Epoch 100/100
#
# Epoch 100: val_loss did not improve from 0.24991
# 1/1 - 0s - loss: 0.2452 - mae: 0.4905 - mape: 245418944.0000 - val_loss: 0.2531 - val_mae: 0.4985 - val_mape: 220724032.0000 - 396ms/epoch - 396ms/step
# 37/37 [==============================] - 2s 16ms/step
# 10/10 [==============================] - 0s 14ms/step
# 10/10 [==============================] - 0s 13ms/step
#
# Evaluation metrics
# Training Data - Loss: 0.2487, MAE: 0.4986, MAPE: 278939840.0000
# Validation Data - Loss: 0.2499, MAE: 0.4998, MAPE: 250731664.0000
# Test Data - Loss: 0.2483, MAE: 0.4982, MAPE: 288647744.0000
# Test Data - eval: 0.0000

# %% [markdown]
# ### CNN + Bi-LSTM model

# %%
def create_model():
  in_seq = Input(shape=(seq_len, 6))

  x = Inception_A(in_seq, 32)
  x = Inception_A(x, 32)
  x = Inception_B(x, 32)
  x = Inception_B(x, 32)
  x = Inception_C(x, 32)
  x = Inception_C(x, 32)

  x = Bidirectional(LSTM(128, return_sequences=True))(x)
  x = Bidirectional(LSTM(128, return_sequences=True))(x)
  x = Bidirectional(LSTM(64, return_sequences=True))(x)

  avg_pool = GlobalAveragePooling1D()(x)
  max_pool = GlobalMaxPooling1D()(x)
  conc = concatenate([avg_pool, max_pool])
  conc = Dense(64, activation="relu")(conc)
  out = Dense(1, activation="sigmoid")(conc)

  model = Model(inputs=in_seq, outputs=out)
  model.compile(loss="mse", optimizer="adam", metrics=['mae', 'mape'])
  return model

model = create_model()

#model.summary()
#callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=2)
callback = tf.keras.callbacks.ModelCheckpoint('CNN+Bi-LSTM.hdf5', monitor='val_loss', save_best_only=True, verbose=1)

model.fit(X_train, y_train,
              batch_size=2048,
              verbose=2,
              callbacks=[callback],
              epochs=epochs,
              #shuffle=True,
              validation_data=(X_val, y_val),)

model = tf.keras.models.load_model('CNN+Bi-LSTM.hdf5')

###############################################################################
'''Calculate predictions and metrics'''

#Calculate predication for training, validation and test data
train_pred = model.predict(X_train)
val_pred = model.predict(X_val)
test_pred = model.predict(X_test)

#Print evaluation metrics for all datasets
train_eval = model.evaluate(X_train, y_train, verbose=0)
val_eval = model.evaluate(X_val, y_val, verbose=0)
test_eval = model.evaluate(X_test, y_test, verbose=0)
print(' ')
print('Evaluation metrics')
print('Training Data - Loss: {:.4f}, MAE: {:.4f}, MAPE: {:.4f}'.format(train_eval[0], train_eval[1], train_eval[2]))
print('Validation Data - Loss: {:.4f}, MAE: {:.4f}, MAPE: {:.4f}'.format(val_eval[0], val_eval[1], val_eval[2]))
print('Test Data - Loss: {:.4f}, MAE: {:.4f}, MAPE: {:.4f}'.format(test_eval[0], test_eval[1], test_eval[2]))

###############################################################################
'''Display results'''

fig = plt.figure(figsize=(15,15))
st = fig.suptitle("CNN + Bi-LSTM Model", fontsize=22)
st.set_y(1.02)

#Plot training data results
ax11 = fig.add_subplot(311)
ax11.plot(train_data[:, 3], label='IBM Closing Returns')
ax11.plot(train_pred, color='yellow', linewidth=3, label='Predicted IBM Closing Returns')
ax11.set_title("Training Data", fontsize=18)
ax11.set_xlabel('Date')
ax11.set_ylabel('IBM Closing Returns')

#Plot validation data results
ax21 = fig.add_subplot(312)
ax21.plot(val_data[:, 3], label='IBM Closing Returns')
ax21.plot(val_pred, color='yellow', linewidth=3, label='Predicted IBM Closing Returns')
ax21.set_title("Validation Data", fontsize=18)
ax21.set_xlabel('Date')
ax21.set_ylabel('IBM Closing Returns')

#Plot test data results
ax31 = fig.add_subplot(313)
ax31.plot(test_data[:, 3], label='IBM Closing Returns')
ax31.plot(test_pred, color='yellow', linewidth=3, label='Predicted IBM Closing Returns')
ax31.set_title("Test Data", fontsize=18)
ax31.set_xlabel('Date')
ax31.set_ylabel('IBM Closing Returns')

plt.tight_layout()
plt.legend(loc='best')
# Out:
# Epoch 1/100
#
# Epoch 1: val_loss improved from inf to 0.25049, saving model to CNN+Bi-LSTM.hdf5
# 1/1 - 55s - loss: 0.2470 - mae: 0.4964 - mape: 271074976.0000 - val_loss: 0.2505 - val_mae: 0.4992 - val_mape: 237159088.0000 - 55s/epoch - 55s/step
# Epoch 2/100
#
# Epoch 2: val_loss improved from 0.25049 to 0.24987, saving model to CNN+Bi-LSTM.hdf5
# 1/1 - 1s - loss: 0.2666 - mae: 0.4679 - mape: 158246544.0000 - val_loss: 0.2499 - val_mae: 0.4997 - val_mape: 249295360.0000 - 920ms/epoch - 920ms/step
# Epoch 3/100
#
# Epoch 3: val_loss did not improve from 0.24987
# 1/1 - 0s - loss: 0.2429 - mae: 0.4857 - mape: 236154128.0000 - val_loss: 0.2501 - val_mae: 0.5001 - val_mape: 257627104.0000 - 368ms/epoch - 368ms/step
# Epoch 4/100
#
# Epoch 4: val_loss did not improve from 0.24987
# 1/1 - 0s - loss: 0.2473 - mae: 0.4968 - mape: 286156960.0000 - val_loss: 0.2499 - val_mae: 0.4999 - val_mape: 252965136.0000 - 375ms/epoch - 375ms/step
# Epoch 5/100
#
# Epoch 5: val_loss did not improve from 0.24987
# 1/1 - 0s - loss: 0.2406 - mae: 0.4872 - mape: 251587744.0000 - val_loss: 0.2499 - val_mae: 0.4997 - val_mape: 248877920.0000 - 403ms/epoch - 403ms/step
# Epoch 6/100
#
# Epoch 6: val_loss did not improve from 0.24987
# 1/1 - 0s - loss: 0.2406 - mae: 0.4789 - mape: 221749472.0000 - val_loss: 0.2499 - val_mae: 0.4997 - val_mape: 249195440.0000 - 389ms/epoch - 389ms/step
# Epoch 7/100
#
# Epoch 7: val_loss did not improve from 0.24987
# 1/1 - 0s - loss: 0.2383 - mae: 0.4759 - mape: 219999520.0000 - val_loss: 0.2499 - val_mae: 0.4998 - val_mape: 251558848.0000 - 377ms/epoch - 377ms/step
# Epoch 8/100
#
# Epoch 8: val_loss did not improve from 0.24987
# 1/1 - 0s - loss: 0.2342 - mae: 0.4765 - mape: 238685776.0000 - val_loss: 0.2500 - val_mae: 0.5000 - val_mape: 254603248.0000 - 402ms/epoch - 402ms/step
# Epoch 9/100
#
# Epoch 9: val_loss did not improve from 0.24987
# 1/1 - 0s - loss: 0.2328 - mae: 0.4765 - mape: 255004800.0000 - val_loss: 0.2500 - val_mae: 0.5000 - val_mape: 254786848.0000 - 383ms/epoch - 383ms/step
# Epoch 10/100
#
# Epoch 10: val_loss did not improve from 0.24987
# 1/1 - 0s - loss: 0.2284 - mae: 0.4680 - mape: 244217440.0000 - val_loss: 0.2499 - val_mae: 0.4999 - val_mape: 253960640.0000 - 353ms/epoch - 353ms/step
# Epoch 11/100
#
# Epoch 11: val_loss did not improve from 0.24987
# 1/1 - 0s - loss: 0.2248 - mae: 0.4553 - mape: 219004784.0000 - val_loss: 0.2500 - val_mae: 0.5000 - val_mape: 254756352.0000 - 372ms/epoch - 372ms/step
# Epoch 12/100
#
# Epoch 12: val_loss did not improve from 0.24987
# 1/1 - 0s - loss: 0.2205 - mae: 0.4460 - mape: 212467280.0000 - val_loss: 0.2501 - val_mae: 0.5001 - val_mape: 257861856.0000 - 370ms/epoch - 370ms/step
# Epoch 13/100
#
# Epoch 13: val_loss did not improve from 0.24987
# 1/1 - 0s - loss: 0.2157 - mae: 0.4411 - mape: 231800352.0000 - val_loss: 0.2501 - val_mae: 0.5001 - val_mape: 257727552.0000 - 328ms/epoch - 328ms/step
# Epoch 14/100
#
# Epoch 14: val_loss did not improve from 0.24987
# 1/1 - 0s - loss: 0.2080 - mae: 0.4239 - mape: 196362528.0000 - val_loss: 0.2504 - val_mae: 0.5003 - val_mape: 261748448.0000 - 332ms/epoch - 332ms/step
# Epoch 15/100
#
# Epoch 15: val_loss did not improve from 0.24987
# 1/1 - 0s - loss: 0.1955 - mae: 0.4117 - mape: 216997840.0000 - val_loss: 0.2504 - val_mae: 0.5003 - val_mape: 261343856.0000 - 363ms/epoch - 363ms/step
# Epoch 16/100
#
# Epoch 16: val_loss did not improve from 0.24987
# 1/1 - 0s - loss: 0.1937 - mae: 0.3880 - mape: 151425088.0000 - val_loss: 0.2519 - val_mae: 0.5008 - val_mape: 272609760.0000 - 330ms/epoch - 330ms/step
# Epoch 17/100
#
# Epoch 17: val_loss did not improve from 0.24987
# 1/1 - 0s - loss: 0.2025 - mae: 0.3982 - mape: 262055024.0000 - val_loss: 0.2512 - val_mae: 0.5006 - val_mape: 268750528.0000 - 331ms/epoch - 331ms/step
# Epoch 18/100
#
# Epoch 18: val_loss did not improve from 0.24987
# 1/1 - 0s - loss: 0.1671 - mae: 0.3468 - mape: 153201984.0000 - val_loss: 0.2515 - val_mae: 0.5007 - val_mape: 270321920.0000 - 330ms/epoch - 330ms/step
# Epoch 19/100
#
# Epoch 19: val_loss did not improve from 0.24987
# 1/1 - 0s - loss: 0.1613 - mae: 0.3286 - mape: 123085640.0000 - val_loss: 0.2534 - val_mae: 0.5011 - val_mape: 280236096.0000 - 333ms/epoch - 333ms/step
# Epoch 20/100
#
# Epoch 20: val_loss did not improve from 0.24987
# 1/1 - 0s - loss: 0.1419 - mae: 0.3081 - mape: 169204864.0000 - val_loss: 0.2550 - val_mae: 0.5014 - val_mape: 286344896.0000 - 330ms/epoch - 330ms/step
# Epoch 21/100
#
# Epoch 21: val_loss did not improve from 0.24987
# 1/1 - 0s - loss: 0.1276 - mae: 0.2832 - mape: 147538800.0000 - val_loss: 0.2560 - val_mae: 0.5015 - val_mape: 289737344.0000 - 331ms/epoch - 331ms/step
# Epoch 22/100
#
# Epoch 22: val_loss did not improve from 0.24987
# 1/1 - 0s - loss: 0.1063 - mae: 0.2437 - mape: 101186880.0000 - val_loss: 0.2596 - val_mae: 0.5020 - val_mape: 300363584.0000 - 329ms/epoch - 329ms/step
# Epoch 23/100
#
# Epoch 23: val_loss did not improve from 0.24987
# 1/1 - 0s - loss: 0.0881 - mae: 0.2116 - mape: 106628744.0000 - val_loss: 0.2652 - val_mae: 0.5025 - val_mape: 313115936.0000 - 368ms/epoch - 368ms/step
# Epoch 24/100
#
# Epoch 24: val_loss did not improve from 0.24987
# 1/1 - 0s - loss: 0.0680 - mae: 0.1722 - mape: 88108336.0000 - val_loss: 0.2751 - val_mae: 0.5033 - val_mape: 331076192.0000 - 330ms/epoch - 330ms/step
# Epoch 25/100
#
# Epoch 25: val_loss did not improve from 0.24987
# 1/1 - 0s - loss: 0.0603 - mae: 0.1485 - mape: 82655600.0000 - val_loss: 0.2834 - val_mae: 0.5038 - val_mape: 343596928.0000 - 340ms/epoch - 340ms/step
# Epoch 26/100
#
# Epoch 26: val_loss did not improve from 0.24987
# 1/1 - 0s - loss: 0.0607 - mae: 0.1337 - mape: 62542624.0000 - val_loss: 0.3014 - val_mae: 0.5048 - val_mape: 365972640.0000 - 380ms/epoch - 380ms/step
# Epoch 27/100
#
# Epoch 27: val_loss did not improve from 0.24987
# 1/1 - 0s - loss: 0.0600 - mae: 0.1231 - mape: 65827664.0000 - val_loss: 0.3175 - val_mae: 0.5056 - val_mape: 382871872.0000 - 333ms/epoch - 333ms/step
# Epoch 28/100
#
# Epoch 28: val_loss did not improve from 0.24987
# 1/1 - 0s - loss: 0.0775 - mae: 0.1376 - mape: 57561912.0000 - val_loss: 0.3547 - val_mae: 0.5070 - val_mape: 415430624.0000 - 338ms/epoch - 338ms/step
# Epoch 29/100
#
# Epoch 29: val_loss did not improve from 0.24987
# 1/1 - 0s - loss: 0.1102 - mae: 0.1639 - mape: 124002640.0000 - val_loss: 0.3606 - val_mae: 0.5072 - val_mape: 420053632.0000 - 332ms/epoch - 332ms/step
# Epoch 30/100
#
# Epoch 30: val_loss did not improve from 0.24987
# 1/1 - 0s - loss: 0.0707 - mae: 0.1184 - mape: 69140152.0000 - val_loss: 0.3624 - val_mae: 0.5073 - val_mape: 421449600.0000 - 329ms/epoch - 329ms/step
# Epoch 31/100
#
# Epoch 31: val_loss did not improve from 0.24987
# 1/1 - 0s - loss: 0.1076 - mae: 0.1592 - mape: 56456772.0000 - val_loss: 0.3797 - val_mae: 0.5079 - val_mape: 434098496.0000 - 368ms/epoch - 368ms/step
# Epoch 32/100
#
# Epoch 32: val_loss did not improve from 0.24987
# 1/1 - 0s - loss: 0.0888 - mae: 0.1379 - mape: 58887396.0000 - val_loss: 0.4054 - val_mae: 0.5087 - val_mape: 451546048.0000 - 329ms/epoch - 329ms/step
# Epoch 33/100
#
# Epoch 33: val_loss did not improve from 0.24987
# 1/1 - 0s - loss: 0.1079 - mae: 0.1616 - mape: 108664272.0000 - val_loss: 0.4047 - val_mae: 0.5086 - val_mape: 451107616.0000 - 331ms/epoch - 331ms/step
# Epoch 34/100
#
# Epoch 34: val_loss did not improve from 0.24987
# 1/1 - 0s - loss: 0.0893 - mae: 0.1489 - mape: 79233312.0000 - val_loss: 0.4040 - val_mae: 0.5086 - val_mape: 450592672.0000 - 335ms/epoch - 335ms/step
# Epoch 35/100
#
# Epoch 35: val_loss did not improve from 0.24987
# 1/1 - 0s - loss: 0.0914 - mae: 0.1633 - mape: 78437472.0000 - val_loss: 0.4057 - val_mae: 0.5086 - val_mape: 451721664.0000 - 365ms/epoch - 365ms/step
# Epoch 36/100
#
# Epoch 36: val_loss did not improve from 0.24987
# 1/1 - 0s - loss: 0.0886 - mae: 0.1726 - mape: 86026840.0000 - val_loss: 0.4131 - val_mae: 0.5088 - val_mape: 456460640.0000 - 334ms/epoch - 334ms/step
# Epoch 37/100
#
# Epoch 37: val_loss did not improve from 0.24987
# 1/1 - 0s - loss: 0.0940 - mae: 0.1878 - mape: 125986912.0000 - val_loss: 0.4124 - val_mae: 0.5088 - val_mape: 456043072.0000 - 368ms/epoch - 368ms/step
# Epoch 38/100
#
# Epoch 38: val_loss did not improve from 0.24987
# 1/1 - 0s - loss: 0.0896 - mae: 0.1883 - mape: 120953448.0000 - val_loss: 0.4084 - val_mae: 0.5087 - val_mape: 453479072.0000 - 332ms/epoch - 332ms/step
# Epoch 39/100
#
# Epoch 39: val_loss did not improve from 0.24987
# 1/1 - 0s - loss: 0.0897 - mae: 0.1871 - mape: 96964632.0000 - val_loss: 0.4104 - val_mae: 0.5088 - val_mape: 454753728.0000 - 383ms/epoch - 383ms/step
# Epoch 40/100
#
# Epoch 40: val_loss did not improve from 0.24987
# 1/1 - 0s - loss: 0.0742 - mae: 0.1671 - mape: 93746016.0000 - val_loss: 0.4145 - val_mae: 0.5089 - val_mape: 457345696.0000 - 360ms/epoch - 360ms/step
# Epoch 41/100
#
# Epoch 41: val_loss did not improve from 0.24987
# 1/1 - 0s - loss: 0.0802 - mae: 0.1684 - mape: 111512872.0000 - val_loss: 0.4106 - val_mae: 0.5088 - val_mape: 454897632.0000 - 397ms/epoch - 397ms/step
# Epoch 42/100
#
# Epoch 42: val_loss did not improve from 0.24987
# 1/1 - 0s - loss: 0.0643 - mae: 0.1424 - mape: 76405200.0000 - val_loss: 0.4084 - val_mae: 0.5087 - val_mape: 453455936.0000 - 399ms/epoch - 399ms/step
# Epoch 43/100
#
# Epoch 43: val_loss did not improve from 0.24987
# 1/1 - 0s - loss: 0.0668 - mae: 0.1380 - mape: 63215972.0000 - val_loss: 0.4092 - val_mae: 0.5087 - val_mape: 453972576.0000 - 389ms/epoch - 389ms/step
# Epoch 44/100
#
# Epoch 44: val_loss did not improve from 0.24987
# 1/1 - 0s - loss: 0.0621 - mae: 0.1291 - mape: 63478260.0000 - val_loss: 0.4104 - val_mae: 0.5088 - val_mape: 454716768.0000 - 378ms/epoch - 378ms/step
# Epoch 45/100
#
# Epoch 45: val_loss did not improve from 0.24987
# 1/1 - 0s - loss: 0.0558 - mae: 0.1193 - mape: 59622528.0000 - val_loss: 0.4115 - val_mae: 0.5088 - val_mape: 455420864.0000 - 341ms/epoch - 341ms/step
# Epoch 46/100
#
# Epoch 46: val_loss did not improve from 0.24987
# 1/1 - 0s - loss: 0.0514 - mae: 0.1109 - mape: 54015760.0000 - val_loss: 0.4132 - val_mae: 0.5089 - val_mape: 456507488.0000 - 366ms/epoch - 366ms/step
# Epoch 47/100
#
# Epoch 47: val_loss did not improve from 0.24987
# 1/1 - 0s - loss: 0.0485 - mae: 0.1057 - mape: 50643036.0000 - val_loss: 0.4151 - val_mae: 0.5089 - val_mape: 457688480.0000 - 330ms/epoch - 330ms/step
# Epoch 48/100
#
# Epoch 48: val_loss did not improve from 0.24987
# 1/1 - 0s - loss: 0.0479 - mae: 0.1028 - mape: 45409760.0000 - val_loss: 0.4186 - val_mae: 0.5090 - val_mape: 459895648.0000 - 332ms/epoch - 332ms/step
# Epoch 49/100
#
# Epoch 49: val_loss did not improve from 0.24987
# 1/1 - 0s - loss: 0.0455 - mae: 0.0981 - mape: 45461428.0000 - val_loss: 0.4223 - val_mae: 0.5091 - val_mape: 462186752.0000 - 334ms/epoch - 334ms/step
# Epoch 50/100
#
# Epoch 50: val_loss did not improve from 0.24987
# 1/1 - 0s - loss: 0.0425 - mae: 0.0916 - mape: 40607888.0000 - val_loss: 0.4265 - val_mae: 0.5092 - val_mape: 464773824.0000 - 333ms/epoch - 333ms/step
# Epoch 51/100
#
# Epoch 51: val_loss did not improve from 0.24987
# 1/1 - 0s - loss: 0.0414 - mae: 0.0886 - mape: 38886828.0000 - val_loss: 0.4313 - val_mae: 0.5094 - val_mape: 467647296.0000 - 337ms/epoch - 337ms/step
# Epoch 52/100
#
# Epoch 52: val_loss did not improve from 0.24987
# 1/1 - 0s - loss: 0.0404 - mae: 0.0870 - mape: 40786336.0000 - val_loss: 0.4350 - val_mae: 0.5095 - val_mape: 469852768.0000 - 336ms/epoch - 336ms/step
# Epoch 53/100
#
# Epoch 53: val_loss did not improve from 0.24987
# 1/1 - 0s - loss: 0.0407 - mae: 0.0839 - mape: 33978692.0000 - val_loss: 0.4402 - val_mae: 0.5096 - val_mape: 472975872.0000 - 367ms/epoch - 367ms/step
# Epoch 54/100
#
# Epoch 54: val_loss did not improve from 0.24987
# 1/1 - 0s - loss: 0.0384 - mae: 0.0795 - mape: 38468864.0000 - val_loss: 0.4444 - val_mae: 0.5097 - val_mape: 475402496.0000 - 339ms/epoch - 339ms/step
# Epoch 55/100
#
# Epoch 55: val_loss did not improve from 0.24987
# 1/1 - 0s - loss: 0.0383 - mae: 0.0776 - mape: 35885172.0000 - val_loss: 0.4487 - val_mae: 0.5098 - val_mape: 477849376.0000 - 339ms/epoch - 339ms/step
# Epoch 56/100
#
# Epoch 56: val_loss did not improve from 0.24987
# 1/1 - 0s - loss: 0.0363 - mae: 0.0742 - mape: 35317088.0000 - val_loss: 0.4524 - val_mae: 0.5099 - val_mape: 479999040.0000 - 377ms/epoch - 377ms/step
# Epoch 57/100
#
# Epoch 57: val_loss did not improve from 0.24987
# 1/1 - 0s - loss: 0.0388 - mae: 0.0744 - mape: 33732884.0000 - val_loss: 0.4563 - val_mae: 0.5100 - val_mape: 482212672.0000 - 373ms/epoch - 373ms/step
# Epoch 58/100
#
# Epoch 58: val_loss did not improve from 0.24987
# 1/1 - 0s - loss: 0.0400 - mae: 0.0754 - mape: 37346544.0000 - val_loss: 0.4591 - val_mae: 0.5101 - val_mape: 483775520.0000 - 342ms/epoch - 342ms/step
# Epoch 59/100
#
# Epoch 59: val_loss did not improve from 0.24987
# 1/1 - 0s - loss: 0.0412 - mae: 0.0764 - mape: 36238124.0000 - val_loss: 0.4617 - val_mae: 0.5102 - val_mape: 485207328.0000 - 373ms/epoch - 373ms/step
# Epoch 60/100
#
# Epoch 60: val_loss did not improve from 0.24987
# 1/1 - 0s - loss: 0.0364 - mae: 0.0714 - mape: 37143608.0000 - val_loss: 0.4631 - val_mae: 0.5102 - val_mape: 485969376.0000 - 367ms/epoch - 367ms/step
# Epoch 61/100
#
# Epoch 61: val_loss did not improve from 0.24987
# 1/1 - 0s - loss: 0.0444 - mae: 0.0777 - mape: 31843972.0000 - val_loss: 0.4652 - val_mae: 0.5103 - val_mape: 487130784.0000 - 332ms/epoch - 332ms/step
# Epoch 62/100
#
# Epoch 62: val_loss did not improve from 0.24987
# 1/1 - 0s - loss: 0.0449 - mae: 0.0786 - mape: 36637308.0000 - val_loss: 0.4666 - val_mae: 0.5103 - val_mape: 487935616.0000 - 341ms/epoch - 341ms/step
# Epoch 63/100
#
# Epoch 63: val_loss did not improve from 0.24987
# 1/1 - 0s - loss: 0.0427 - mae: 0.0775 - mape: 32555234.0000 - val_loss: 0.4690 - val_mae: 0.5104 - val_mape: 489236800.0000 - 374ms/epoch - 374ms/step
# Epoch 64/100
#
# Epoch 64: val_loss did not improve from 0.24987
# 1/1 - 0s - loss: 0.0495 - mae: 0.0864 - mape: 50782820.0000 - val_loss: 0.4686 - val_mae: 0.5103 - val_mape: 489000416.0000 - 362ms/epoch - 362ms/step
# Epoch 65/100
#
# Epoch 65: val_loss did not improve from 0.24987
# 1/1 - 0s - loss: 0.0527 - mae: 0.0900 - mape: 33779820.0000 - val_loss: 0.4695 - val_mae: 0.5104 - val_mape: 489513632.0000 - 371ms/epoch - 371ms/step
# Epoch 66/100
#
# Epoch 66: val_loss did not improve from 0.24987
# 1/1 - 0s - loss: 0.0583 - mae: 0.0991 - mape: 41239556.0000 - val_loss: 0.4704 - val_mae: 0.5104 - val_mape: 489974336.0000 - 337ms/epoch - 337ms/step
# Epoch 67/100
#
# Epoch 67: val_loss did not improve from 0.24987
# 1/1 - 0s - loss: 0.0604 - mae: 0.1064 - mape: 50375944.0000 - val_loss: 0.4707 - val_mae: 0.5104 - val_mape: 490131136.0000 - 371ms/epoch - 371ms/step
# Epoch 68/100
#
# Epoch 68: val_loss did not improve from 0.24987
# 1/1 - 0s - loss: 0.0587 - mae: 0.1084 - mape: 49750036.0000 - val_loss: 0.4723 - val_mae: 0.5104 - val_mape: 491006272.0000 - 373ms/epoch - 373ms/step
# Epoch 69/100
#
# Epoch 69: val_loss did not improve from 0.24987
# 1/1 - 0s - loss: 0.0604 - mae: 0.1197 - mape: 74453496.0000 - val_loss: 0.4727 - val_mae: 0.5104 - val_mape: 491247840.0000 - 369ms/epoch - 369ms/step
# Epoch 70/100
#
# Epoch 70: val_loss did not improve from 0.24987
# 1/1 - 0s - loss: 0.0611 - mae: 0.1286 - mape: 87113344.0000 - val_loss: 0.4713 - val_mae: 0.5104 - val_mape: 490503456.0000 - 367ms/epoch - 367ms/step
# Epoch 71/100
#
# Epoch 71: val_loss did not improve from 0.24987
# 1/1 - 0s - loss: 0.0573 - mae: 0.1203 - mape: 66733404.0000 - val_loss: 0.4714 - val_mae: 0.5104 - val_mape: 490531392.0000 - 372ms/epoch - 372ms/step
# Epoch 72/100
#
# Epoch 72: val_loss did not improve from 0.24987
# 1/1 - 0s - loss: 0.0501 - mae: 0.1109 - mape: 74136304.0000 - val_loss: 0.4703 - val_mae: 0.5104 - val_mape: 489956576.0000 - 354ms/epoch - 354ms/step
# Epoch 73/100
#
# Epoch 73: val_loss did not improve from 0.24987
# 1/1 - 0s - loss: 0.0460 - mae: 0.1017 - mape: 66120156.0000 - val_loss: 0.4686 - val_mae: 0.5103 - val_mape: 489014144.0000 - 387ms/epoch - 387ms/step
# Epoch 74/100
#
# Epoch 74: val_loss did not improve from 0.24987
# 1/1 - 0s - loss: 0.0423 - mae: 0.0896 - mape: 51761756.0000 - val_loss: 0.4673 - val_mae: 0.5103 - val_mape: 488277920.0000 - 396ms/epoch - 396ms/step
# Epoch 75/100
#
# Epoch 75: val_loss did not improve from 0.24987
# 1/1 - 0s - loss: 0.0385 - mae: 0.0811 - mape: 46755384.0000 - val_loss: 0.4661 - val_mae: 0.5103 - val_mape: 487661024.0000 - 399ms/epoch - 399ms/step
# Epoch 76/100
#
# Epoch 76: val_loss did not improve from 0.24987
# 1/1 - 0s - loss: 0.0388 - mae: 0.0786 - mape: 46251340.0000 - val_loss: 0.4643 - val_mae: 0.5102 - val_mape: 486655968.0000 - 387ms/epoch - 387ms/step
# Epoch 77/100
#
# Epoch 77: val_loss did not improve from 0.24987
# 1/1 - 0s - loss: 0.0363 - mae: 0.0726 - mape: 39166932.0000 - val_loss: 0.4625 - val_mae: 0.5102 - val_mape: 485634016.0000 - 388ms/epoch - 388ms/step
# Epoch 78/100
#
# Epoch 78: val_loss did not improve from 0.24987
# 1/1 - 0s - loss: 0.0364 - mae: 0.0703 - mape: 35716996.0000 - val_loss: 0.4608 - val_mae: 0.5101 - val_mape: 484736224.0000 - 337ms/epoch - 337ms/step
# Epoch 79/100
#
# Epoch 79: val_loss did not improve from 0.24987
# 1/1 - 0s - loss: 0.0359 - mae: 0.0688 - mape: 35131688.0000 - val_loss: 0.4587 - val_mae: 0.5101 - val_mape: 483524288.0000 - 368ms/epoch - 368ms/step
# Epoch 80/100
#
# Epoch 80: val_loss did not improve from 0.24987
# 1/1 - 0s - loss: 0.0365 - mae: 0.0687 - mape: 30550368.0000 - val_loss: 0.4577 - val_mae: 0.5101 - val_mape: 482952768.0000 - 371ms/epoch - 371ms/step
# Epoch 81/100
#
# Epoch 81: val_loss did not improve from 0.24987
# 1/1 - 0s - loss: 0.0426 - mae: 0.0759 - mape: 41267136.0000 - val_loss: 0.4530 - val_mae: 0.5099 - val_mape: 480330848.0000 - 338ms/epoch - 338ms/step
# Epoch 82/100
#
# Epoch 82: val_loss did not improve from 0.24987
# 1/1 - 0s - loss: 0.0744 - mae: 0.1084 - mape: 26574386.0000 - val_loss: 0.4541 - val_mae: 0.5100 - val_mape: 480944192.0000 - 341ms/epoch - 341ms/step
# Epoch 83/100
#
# Epoch 83: val_loss did not improve from 0.24987
# 1/1 - 0s - loss: 0.0526 - mae: 0.0851 - mape: 37601868.0000 - val_loss: 0.4539 - val_mae: 0.5100 - val_mape: 480822688.0000 - 342ms/epoch - 342ms/step
# Epoch 84/100
#
# Epoch 84: val_loss did not improve from 0.24987
# 1/1 - 0s - loss: 0.0764 - mae: 0.1120 - mape: 67593512.0000 - val_loss: 0.4486 - val_mae: 0.5098 - val_mape: 477802400.0000 - 343ms/epoch - 343ms/step
# Epoch 85/100
#
# Epoch 85: val_loss did not improve from 0.24987
# 1/1 - 0s - loss: 0.0652 - mae: 0.1009 - mape: 45553548.0000 - val_loss: 0.4408 - val_mae: 0.5097 - val_mape: 473294528.0000 - 347ms/epoch - 347ms/step
# Epoch 86/100
#
# Epoch 86: val_loss did not improve from 0.24987
# 1/1 - 0s - loss: 0.1011 - mae: 0.1387 - mape: 29138414.0000 - val_loss: 0.4380 - val_mae: 0.5096 - val_mape: 471625472.0000 - 373ms/epoch - 373ms/step
# Epoch 87/100
#
# Epoch 87: val_loss did not improve from 0.24987
# 1/1 - 0s - loss: 0.0833 - mae: 0.1237 - mape: 35879592.0000 - val_loss: 0.4380 - val_mae: 0.5096 - val_mape: 471627968.0000 - 340ms/epoch - 340ms/step
# Epoch 88/100
#
# Epoch 88: val_loss did not improve from 0.24987
# 1/1 - 0s - loss: 0.0810 - mae: 0.1264 - mape: 58382796.0000 - val_loss: 0.4343 - val_mae: 0.5095 - val_mape: 469453472.0000 - 370ms/epoch - 370ms/step
# Epoch 89/100
#
# Epoch 89: val_loss did not improve from 0.24987
# 1/1 - 0s - loss: 0.0796 - mae: 0.1304 - mape: 66008540.0000 - val_loss: 0.4264 - val_mae: 0.5093 - val_mape: 464731904.0000 - 375ms/epoch - 375ms/step
# Epoch 90/100
#
# Epoch 90: val_loss did not improve from 0.24987
# 1/1 - 0s - loss: 0.0751 - mae: 0.1297 - mape: 55274468.0000 - val_loss: 0.4192 - val_mae: 0.5091 - val_mape: 460286688.0000 - 340ms/epoch - 340ms/step
# Epoch 91/100
#
# Epoch 91: val_loss did not improve from 0.24987
# 1/1 - 0s - loss: 0.0702 - mae: 0.1317 - mape: 58885388.0000 - val_loss: 0.4098 - val_mae: 0.5090 - val_mape: 454348320.0000 - 369ms/epoch - 369ms/step
# Epoch 92/100
#
# Epoch 92: val_loss did not improve from 0.24987
# 1/1 - 0s - loss: 0.0689 - mae: 0.1387 - mape: 64318272.0000 - val_loss: 0.3988 - val_mae: 0.5088 - val_mape: 447095936.0000 - 340ms/epoch - 340ms/step
# Epoch 93/100
#
# Epoch 93: val_loss did not improve from 0.24987
# 1/1 - 0s - loss: 0.0646 - mae: 0.1403 - mape: 67311416.0000 - val_loss: 0.3866 - val_mae: 0.5089 - val_mape: 438749248.0000 - 338ms/epoch - 338ms/step
# Epoch 94/100
#
# Epoch 94: val_loss did not improve from 0.24987
# 1/1 - 0s - loss: 0.0615 - mae: 0.1427 - mape: 67512616.0000 - val_loss: 0.3795 - val_mae: 0.5098 - val_mape: 433114848.0000 - 372ms/epoch - 372ms/step
# Epoch 95/100
#
# Epoch 95: val_loss did not improve from 0.24987
# 1/1 - 0s - loss: 0.0586 - mae: 0.1426 - mape: 71351360.0000 - val_loss: 0.3799 - val_mae: 0.5101 - val_mape: 432734592.0000 - 372ms/epoch - 372ms/step
# Epoch 96/100
#
# Epoch 96: val_loss did not improve from 0.24987
# 1/1 - 0s - loss: 0.0572 - mae: 0.1422 - mape: 75365200.0000 - val_loss: 0.3859 - val_mae: 0.5105 - val_mape: 436936320.0000 - 371ms/epoch - 371ms/step
# Epoch 97/100
#
# Epoch 97: val_loss did not improve from 0.24987
# 1/1 - 0s - loss: 0.0541 - mae: 0.1353 - mape: 72747280.0000 - val_loss: 0.3963 - val_mae: 0.5108 - val_mape: 444618688.0000 - 369ms/epoch - 369ms/step
# Epoch 98/100
#
# Epoch 98: val_loss did not improve from 0.24987
# 1/1 - 0s - loss: 0.0523 - mae: 0.1265 - mape: 65716028.0000 - val_loss: 0.4105 - val_mae: 0.5105 - val_mape: 454375392.0000 - 336ms/epoch - 336ms/step
# Epoch 99/100
#
# Epoch 99: val_loss did not improve from 0.24987
# 1/1 - 0s - loss: 0.0508 - mae: 0.1182 - mape: 61900172.0000 - val_loss: 0.4208 - val_mae: 0.5106 - val_mape: 460952864.0000 - 337ms/epoch - 337ms/step
# Epoch 100/100
#
# Epoch 100: val_loss did not improve from 0.24987
# 1/1 - 0s - loss: 0.0491 - mae: 0.1109 - mape: 57757864.0000 - val_loss: 0.4295 - val_mae: 0.5107 - val_mape: 466329824.0000 - 371ms/epoch - 371ms/step
# 37/37 [==============================] - 4s 22ms/step
# 10/10 [==============================] - 0s 47ms/step
# 10/10 [==============================] - 0s 19ms/step
#
# Evaluation metrics
# Training Data - Loss: 0.2484, MAE: 0.4983, MAPE: 277398656.0000
# Validation Data - Loss: 0.2499, MAE: 0.4997, MAPE: 249295360.0000
# Test Data - Loss: 0.2479, MAE: 0.4978, MAPE: 287175936.0000

# %% [markdown]
# ## **Conculsion 1**
# When interpreting at the evaluation metrics it seems that the networks are predicting the next day closing price returns very well. The Bi-LSTM and CNN+Bi-LSTM networks have a **mean average percentage error** **(MAPE)** of  `3.58` and `3.84` for the validation set and `4.26` and `4.53` for the test set.
# Making it also obvious that the Bi-LSTM network is better than the CNN+Bi-LSTM network, which honestly surprised me.
#
# However, when taking a glance at the graphs of the validation and test set it becomes clear that the networks have merely found the center point of the return distributions. Over the entire course of the time series the networks do not divert greatly from the center.
#
# It seems that the right and left tail of the stock return distribution are not derivable from price data alone.
#
# I do have the following **hypotheses** that provide more room for investigation and might lead to better results.
#
# #### **Hypotheses**
#
# 1. The stock returns seem very rugged, which could make the networks interpret the distribution tails as semi-random. --> smooth returns with **moving average**
#
# 2. We do need more price data to derive temporal dependencies of the time series and get a better understanding of the distribution tails. --> Obtain **more price data** of different stocks, etfs, etc.
#
# 3. In order to predict the stock return distribution tails more accurately include additional features e.g. **financial news, company's balance sheet and P&L**
#
# The first hypothesis we'll also implement in this notebook.
#
# The second and third hypothesis will be addressed at a later stage.

# %% [markdown]
# # **Moving Average Analysis**

# %% [markdown]
# ## Loading IBM data again to apply a moving average effect

# %%
IBM_path = 'IBM.csv'

df = pd.read_csv(IBM_path, delimiter=',', usecols=['Date', 'Open', 'High', 'Low', 'Close', 'Volume'])

# Replace 0 to avoid dividing by 0 later on
df['Volume'].replace(to_replace=0, method='ffill', inplace=True)
df.sort_values('Date', inplace=True)

# Apply moving average with a window of 10 days to all columns
df[['Open', 'High', 'Low', 'Close', 'Volume']] = df[['Open', 'High', 'Low', 'Close', 'Volume']].rolling(10).mean()

# Drop all rows with NaN values
df.dropna(how='any', axis=0, inplace=True)

df.head()
# Out:
#           Date       Open       High        Low      Close     Volume
# 9   1988-08-12  29.493308  29.579948  29.203513  29.314054  5576937.3
# 10  1988-08-15  29.293141  29.373805  28.955545  29.048160  5818730.7
# 11  1988-08-16  29.018284  29.131811  28.716539  28.809154  6180897.7
# 12  1988-08-17  28.779278  28.889818  28.435707  28.543260  5991069.6
# 13  1988-08-18  28.522347  28.650813  28.199689  28.313217  5905130.3

# %% [markdown]
# ## Moving Average - Plot daily IBM closing prices

# %%
plt.figure(figsize=(15, 5))
plt.plot(df['Close'])
plt.xticks(range(0, df.shape[0], 1464), df['Date'].loc[::1464], rotation=0)
plt.ylabel('Price', fontsize=18)
plt.title("Close Price - Moving Average", fontsize=20)
plt.legend(['Close Price'], fontsize='x-large', loc='best')
plt.show()

# %% [markdown]
# ## Moving Average - Plot daily IBM volumes

# %%
plt.figure(figsize=(15, 5))
plt.plot(df['Volume'])
plt.xticks(range(0, df.shape[0], 1464), df['Date'].loc[::1464], rotation=0)
plt.ylabel('Volume', fontsize=18)
plt.title("Volume - Moving Average", fontsize=20)
plt.legend(['Volume'], fontsize='x-large', loc='best')
plt.show()

# %% [markdown]
# ## Moving Average - Calculate normalized percentage change for all columns

# %%
'''Calculate percentage change'''

df['Open'] = df['Open'].pct_change() # Create arithmetic returns column
df['High'] = df['High'].pct_change() # Create arithmetic returns column
df['Low'] = df['Low'].pct_change() # Create arithmetic returns column
df['Close'] = df['Close'].pct_change() # Create arithmetic returns column
df['Volume'] = df['Volume'].pct_change()

df.dropna(how='any', axis=0, inplace=True) # Drop all rows with NaN values

###############################################################################
'''Normalize price columns'''

min_return = min(df[['Open', 'High', 'Low', 'Close']].min(axis=0))
max_return = max(df[['Open', 'High', 'Low', 'Close']].max(axis=0))

# Min-max normalize price columns (0-1 range)
df['Open'] = (df['Open'] - min_return) / (max_return - min_return)
df['High'] = (df['High'] - min_return) / (max_return - min_return)
df['Low'] = (df['Low'] - min_return) / (max_return - min_return)
df['Close'] = (df['Close'] - min_return) / (max_return - min_return)

###############################################################################
'''Normalize volume column'''

min_volume = df['Volume'].min(axis=0)
max_volume = df['Volume'].max(axis=0)

# Min-max normalize volume columns (0-1 range)
df['Volume'] = (df['Volume'] - min_volume) / (max_volume - min_volume)

###############################################################################
'''Create training, validation and test split'''

times = sorted(df.index.values)
last_10pct = sorted(df.index.values)[-int(0.1*len(times))] # Last 10% of series
last_20pct = sorted(df.index.values)[-int(0.2*len(times))] # Last 20% of series

df_train = df[(df.index < last_20pct)]  # Training data are 80% of total data
df_val = df[(df.index >= last_20pct) & (df.index < last_10pct)]
df_test = df[(df.index >= last_10pct)]

# Remove date column
df_train.drop(columns=['Date'], inplace=True)
df_val.drop(columns=['Date'], inplace=True)
df_test.drop(columns=['Date'], inplace=True)

# Convert pandas columns into arrays
train_data = df_train.values
val_data = df_val.values
test_data = df_test.values
print('Training data shape: {}'.format(train_data.shape))
print('Validation data shape: {}'.format(val_data.shape))
print('Test data shape: {}'.format(test_data.shape))

df_train.head()
# Out:
# Training data shape: (7048, 5)
# Validation data shape: (881, 5)
# Test data shape: (880, 5)
#         Open      High       Low     Close    Volume
# 10  0.409703  0.406833  0.382852  0.373722  0.375957
# 11  0.368799  0.386833  0.386583  0.386998  0.390538
# 12  0.386864  0.385754  0.362553  0.371217  0.318771
# 13  0.375973  0.386288  0.385861  0.389652  0.331408
# 14  0.401111  0.395058  0.369744  0.368670  0.375246

# %% [markdown]
# ## Moving Average - Plot daily changes of close prices and volume

# %%
fig = plt.figure(figsize=(15,10))
st = fig.suptitle("Data Separation", fontsize=20)
st.set_y(0.92)

###############################################################################

ax1 = fig.add_subplot(211)
ax1.plot(np.arange(train_data.shape[0]), df_train['Close'], label='Training data')

ax1.plot(np.arange(train_data.shape[0],
                   train_data.shape[0]+val_data.shape[0]), df_val['Close'], label='Validation data')

ax1.plot(np.arange(train_data.shape[0]+val_data.shape[0],
                   train_data.shape[0]+val_data.shape[0]+test_data.shape[0]), df_test['Close'], label='Test data')
ax1.set_xlabel('Date')
ax1.set_ylabel('Normalized Closing Returns')

###############################################################################

ax2 = fig.add_subplot(212)
ax2.plot(np.arange(train_data.shape[0]), df_train['Volume'], label='Training data')

ax2.plot(np.arange(train_data.shape[0],
                   train_data.shape[0]+val_data.shape[0]), df_val['Volume'], label='Validation data')

ax2.plot(np.arange(train_data.shape[0]+val_data.shape[0],
                   train_data.shape[0]+val_data.shape[0]+test_data.shape[0]), df_test['Volume'], label='Test data')
ax2.set_xlabel('Date')
ax2.set_ylabel('Normalized Volume Changes')

plt.legend(loc='best')

# %% [markdown]
# ## Moving Average - Create chunks of training, validation and test data

# %%
# Training data
X_train, y_train = [], []
for i in range(seq_len, len(train_data)):
  X_train.append(train_data[i-seq_len:i]) # Chunks of training data with a length of 128 df-rows
  y_train.append(train_data[:, 3][i]) #Value of 4th column (Close Price) of df-row 128+1
X_train, y_train = np.array(X_train), np.array(y_train)

###############################################################################

# Validation data
X_val, y_val = [], []
for i in range(seq_len, len(val_data)):
    X_val.append(val_data[i-seq_len:i])
    y_val.append(val_data[:, 3][i])
X_val, y_val = np.array(X_val), np.array(y_val)

###############################################################################

# Test data
X_test, y_test = [], []
for i in range(seq_len, len(test_data)):
    X_test.append(test_data[i-seq_len:i])
    y_test.append(test_data[:, 3][i])
X_test, y_test = np.array(X_test), np.array(y_test)

print(X_train.shape, y_train.shape)
print(X_val.shape, y_val.shape)
# Out:
# (6920, 128, 5) (6920,)
# (753, 128, 5) (753,)

# %% [markdown]
# # **Moving Average - Testing different model architectures**

# %% [markdown]
# ### Moving Average - Bi-LSTM model

# %%
def create_model():
  in_seq = Input(shape = (seq_len, 5))

  x = Bidirectional(LSTM(128, return_sequences=True))(in_seq)
  x = Bidirectional(LSTM(128, return_sequences=True))(x)
  x = Bidirectional(LSTM(64, return_sequences=True))(x)

  avg_pool = GlobalAveragePooling1D()(x)
  max_pool = GlobalMaxPooling1D()(x)
  conc = concatenate([avg_pool, max_pool])
  conc = Dense(64, activation="relu")(conc)
  out = Dense(1, activation="sigmoid")(conc)

  model = Model(inputs=in_seq, outputs=out)
  model.compile(loss="mse", optimizer="adam", metrics=['mae', 'mape'])
  return model

model = create_model()

#model.summary()
#callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=2)
callback = tf.keras.callbacks.ModelCheckpoint('Bi-LSTM.hdf5', monitor='val_loss', save_best_only=True, verbose=1)

model.fit(X_train, y_train,
              batch_size=2048,
              verbose=2,
              callbacks=[callback],
              epochs=epochs,
              #shuffle=True,
              validation_data=(X_val, y_val),)

model = tf.keras.models.load_model('Bi-LSTM.hdf5')

###############################################################################
'''Calculate predictions and metrics'''

#Calculate predication for training, validation and test data
train_pred = model.predict(X_train)
val_pred = model.predict(X_val)
test_pred = model.predict(X_test)

#Print evaluation metrics for all datasets
train_eval = model.evaluate(X_train, y_train, verbose=0)
val_eval = model.evaluate(X_val, y_val, verbose=0)
test_eval = model.evaluate(X_test, y_test, verbose=0)
print(' ')
print('Evaluation metrics')
print('Training Data - Loss: {:.4f}, MAE: {:.4f}, MAPE: {:.4f}'.format(train_eval[0], train_eval[1], train_eval[2]))
print('Validation Data - Loss: {:.4f}, MAE: {:.4f}, MAPE: {:.4f}'.format(val_eval[0], val_eval[1], val_eval[2]))
print('Test Data - Loss: {:.4f}, MAE: {:.4f}, MAPE: {:.4f}'.format(test_eval[0], test_eval[1], test_eval[2]))

###############################################################################
'''Display results'''

fig = plt.figure(figsize=(15,15))
st = fig.suptitle("Moving Average - Bi-LSTM Model", fontsize=22)
st.set_y(1.02)

#Plot training data results
ax11 = fig.add_subplot(311)
ax11.plot(train_data[:, 3], label='IBM Closing Returns')
ax11.plot(train_pred, label='Predicted IBM Closing Returns')
ax11.set_title("Training Data", fontsize=18)
ax11.set_xlabel('Date')
ax11.set_ylabel('IBM Closing Returns')

#Plot validation data results
ax21 = fig.add_subplot(312)
ax21.plot(val_data[:, 3], label='IBM Closing Returns')
ax21.plot(val_pred, label='Predicted IBM Closing Returns')
ax21.set_title("Validation Data", fontsize=18)
ax21.set_xlabel('Date')
ax21.set_ylabel('IBM Closing Returns')

#Plot test data results
ax31 = fig.add_subplot(313)
ax31.plot(test_data[:, 3], label='IBM Closing Returns')
ax31.plot(test_pred, label='Predicted IBM Closing Returns')
ax31.set_title("Test Data", fontsize=18)
ax31.set_xlabel('Date')
ax31.set_ylabel('IBM Closing Returns')

plt.tight_layout()
plt.legend(loc='best')
# Out:
# 2023-08-02 15:00:31.300911: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-08-02 15:00:31.303718: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-08-02 15:00:31.305648: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-08-02 15:00:31.458624: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis' with dtype int32 and shape [1]
# 	 [[{{node gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis}}]]
# 2023-08-02 15:00:31.511508: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-08-02 15:00:31.514221: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-08-02 15:00:31.516335: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-08-02 15:00:31.739453: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-08-02 15:00:31.741504: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-08-02 15:00:31.743420: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-08-02 15:00:31.886597: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis' with dtype int32 and shape [1]
# 	 [[{{node gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis}}]]
# 2023-08-02 15:00:31.937840: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-08-02 15:00:31.939964: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-08-02 15:00:31.941568: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-08-02 15:00:32.153700: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-08-02 15:00:32.155873: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-08-02 15:00:32.157952: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-08-02 15:00:32.302384: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis' with dtype int32 and shape [1]
# 	 [[{{node gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis}}]]
# 2023-08-02 15:00:32.353347: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# Epoch 1/5
# 2023-08-02 15:00:32.355795: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-08-02 15:00:32.358420: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-08-02 15:00:32.710006: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-08-02 15:00:32.712418: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-08-02 15:00:32.714266: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-08-02 15:00:32.878506: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis' with dtype int32 and shape [1]
# 	 [[{{node gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis}}]]
# 2023-08-02 15:00:32.940260: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-08-02 15:00:32.942736: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-08-02 15:00:32.944563: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-08-02 15:00:33.148700: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-08-02 15:00:33.151456: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-08-02 15:00:33.153467: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-08-02 15:00:33.306453: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis' with dtype int32 and shape [1]
# 	 [[{{node gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis}}]]
# 2023-08-02 15:00:33.364203: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-08-02 15:00:33.366878: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-08-02 15:00:33.368732: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-08-02 15:00:34.432146: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-08-02 15:00:34.435319: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-08-02 15:00:34.437529: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-08-02 15:00:34.599903: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis' with dtype int32 and shape [1]
# 	 [[{{node gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis}}]]
# 2023-08-02 15:00:34.658765: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-08-02 15:00:34.661646: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-08-02 15:00:34.663600: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-08-02 15:00:35.210188: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis' with dtype int32 and shape [1]
# 	 [[{{node gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis}}]]
# 2023-08-02 15:00:35.662537: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis' with dtype int32 and shape [1]
# 	 [[{{node gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis}}]]
# 2023-08-02 15:00:36.101791: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis' with dtype int32 and shape [1]
# 	 [[{{node gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis}}]]
# 2023-08-02 15:00:36.862608: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-08-02 15:00:36.865619: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-08-02 15:00:36.867551: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-08-02 15:00:37.020343: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis' with dtype int32 and shape [1]
# 	 [[{{node gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis}}]]
# 2023-08-02 15:00:37.076671: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-08-02 15:00:37.078980: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-08-02 15:00:37.080743: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-08-02 15:00:37.287421: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-08-02 15:00:37.290039: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-08-02 15:00:37.292068: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-08-02 15:00:37.451225: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis' with dtype int32 and shape [1]
# 	 [[{{node gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis}}]]
# 2023-08-02 15:00:37.508136: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-08-02 15:00:37.510425: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-08-02 15:00:37.512415: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-08-02 15:00:37.719559: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-08-02 15:00:37.721931: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-08-02 15:00:37.723629: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-08-02 15:00:37.874286: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis' with dtype int32 and shape [1]
# 	 [[{{node gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis}}]]
# 2023-08-02 15:00:37.931437: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-08-02 15:00:37.934299: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-08-02 15:00:37.936378: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-08-02 15:00:38.506704: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis' with dtype int32 and shape [1]
# 	 [[{{node gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis}}]]
# 2023-08-02 15:00:38.951698: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis' with dtype int32 and shape [1]
# 	 [[{{node gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis}}]]
# 2023-08-02 15:00:39.386126: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis' with dtype int32 and shape [1]
# 	 [[{{node gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis}}]]
# 2023-08-02 15:01:40.277469: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-08-02 15:01:40.280034: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-08-02 15:01:40.282157: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-08-02 15:01:40.425623: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis' with dtype int32 and shape [1]
# 	 [[{{node gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis}}]]
# 2023-08-02 15:01:40.475218: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-08-02 15:01:40.477085: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-08-02 15:01:40.479142: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-08-02 15:01:40.681240: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-08-02 15:01:40.683981: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-08-02 15:01:40.686098: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-08-02 15:01:40.831004: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis' with dtype int32 and shape [1]
# 	 [[{{node gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis}}]]
# 2023-08-02 15:01:40.883506: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-08-02 15:01:40.886234: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-08-02 15:01:40.888370: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-08-02 15:01:41.084253: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-08-02 15:01:41.086386: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-08-02 15:01:41.088792: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-08-02 15:01:41.234384: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis' with dtype int32 and shape [1]
# 	 [[{{node gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis}}]]
# 2023-08-02 15:01:41.284141: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-08-02 15:01:41.286121: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-08-02 15:01:41.288089: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# Epoch 1: val_loss improved from inf to 0.00443, saving model to Bi-LSTM.hdf5
# 4/4 - 72s - loss: 0.0093 - mae: 0.0732 - mape: 15.2024 - val_loss: 0.0044 - val_mae: 0.0482 - val_mape: 10.3872 - 72s/epoch - 18s/step
# Epoch 2/5
#
# Epoch 2: val_loss did not improve from 0.00443
# 4/4 - 60s - loss: 0.0072 - mae: 0.0623 - mape: 13.3255 - val_loss: 0.0047 - val_mae: 0.0492 - val_mape: 10.7804 - 60s/epoch - 15s/step
# Epoch 3/5
#
# Epoch 3: val_loss did not improve from 0.00443
# 4/4 - 60s - loss: 0.0072 - mae: 0.0621 - mape: 13.4117 - val_loss: 0.0045 - val_mae: 0.0484 - val_mape: 10.5246 - 60s/epoch - 15s/step
# Epoch 4/5
#
# Epoch 4: val_loss improved from 0.00443 to 0.00442, saving model to Bi-LSTM.hdf5
# 4/4 - 79s - loss: 0.0071 - mae: 0.0619 - mape: 13.4666 - val_loss: 0.0044 - val_mae: 0.0481 - val_mape: 10.3957 - 79s/epoch - 20s/step
# Epoch 5/5
#
# Epoch 5: val_loss improved from 0.00442 to 0.00431, saving model to Bi-LSTM.hdf5
# 4/4 - 75s - loss: 0.0071 - mae: 0.0615 - mape: 13.3872 - val_loss: 0.0043 - val_mae: 0.0480 - val_mape: 10.2213 - 75s/epoch - 19s/step
# 2023-08-02 15:06:18.619868: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-08-02 15:06:18.622329: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-08-02 15:06:18.624357: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-08-02 15:06:18.826322: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis' with dtype int32 and shape [1]
# 	 [[{{node gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis}}]]
# 2023-08-02 15:06:18.915825: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-08-02 15:06:18.918547: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-08-02 15:06:18.921794: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-08-02 15:06:19.240020: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-08-02 15:06:19.242582: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-08-02 15:06:19.244605: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-08-02 15:06:19.470151: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis' with dtype int32 and shape [1]
# 	 [[{{node gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis}}]]
# 2023-08-02 15:06:19.561401: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-08-02 15:06:19.563474: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-08-02 15:06:19.565146: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-08-02 15:06:19.868814: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-08-02 15:06:19.871923: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-08-02 15:06:19.874042: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-08-02 15:06:20.081994: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis' with dtype int32 and shape [1]
# 	 [[{{node gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis}}]]
# 2023-08-02 15:06:20.167426: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-08-02 15:06:20.169973: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-08-02 15:06:20.172274: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-08-02 15:06:20.687246: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-08-02 15:06:20.690586: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-08-02 15:06:20.692732: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-08-02 15:06:20.897046: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis' with dtype int32 and shape [1]
# 	 [[{{node gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis}}]]
# 2023-08-02 15:06:20.977850: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-08-02 15:06:20.979948: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-08-02 15:06:20.981860: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-08-02 15:06:21.263071: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-08-02 15:06:21.265189: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-08-02 15:06:21.266934: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-08-02 15:06:21.472421: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis' with dtype int32 and shape [1]
# 	 [[{{node gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis}}]]
# 2023-08-02 15:06:21.555968: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-08-02 15:06:21.558949: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-08-02 15:06:21.561465: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-08-02 15:06:22.312630: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-08-02 15:06:22.315779: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-08-02 15:06:22.317787: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-08-02 15:06:22.532976: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis' with dtype int32 and shape [1]
# 	 [[{{node gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis}}]]
# 2023-08-02 15:06:22.613739: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-08-02 15:06:22.615939: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-08-02 15:06:22.617818: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 217/217 [==============================] - 49s 214ms/step
# 24/24 [==============================] - 5s 213ms/step
# 24/24 [==============================] - 5s 214ms/step
# 2023-08-02 15:07:25.781726: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-08-02 15:07:25.783879: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-08-02 15:07:25.785978: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-08-02 15:07:26.001552: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis' with dtype int32 and shape [1]
# 	 [[{{node gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis}}]]
# 2023-08-02 15:07:26.092904: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-08-02 15:07:26.095046: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-08-02 15:07:26.096738: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-08-02 15:07:26.382822: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-08-02 15:07:26.384859: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-08-02 15:07:26.387033: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-08-02 15:07:26.595936: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis' with dtype int32 and shape [1]
# 	 [[{{node gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis}}]]
# 2023-08-02 15:07:26.689339: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-08-02 15:07:26.691895: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-08-02 15:07:26.694296: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-08-02 15:07:26.986123: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-08-02 15:07:26.989015: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-08-02 15:07:26.991751: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-08-02 15:07:27.207183: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis' with dtype int32 and shape [1]
# 	 [[{{node gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis}}]]
# 2023-08-02 15:07:27.288107: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-08-02 15:07:27.290843: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-08-02 15:07:27.292939: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
#
# Evaluation metrics
# Training Data - Loss: 0.0071, MAE: 0.0615, MAPE: 13.1423
# Validation Data - Loss: 0.0043, MAE: 0.0480, MAPE: 10.2213
# Test Data - Loss: 0.0051, MAE: 0.0562, MAPE: 11.2756

# %% [markdown]
# ### Moving Average - CNN + Bi-LSTM model

# %%
def create_model():
  in_seq = Input(shape=(seq_len, 5))

  x = Inception_A(in_seq, 32)
  x = Inception_A(x, 32)
  x = Inception_B(x, 32)
  x = Inception_B(x, 32)
  x = Inception_C(x, 32)
  x = Inception_C(x, 32)

  x = Bidirectional(LSTM(128, return_sequences=True))(x)
  x = Bidirectional(LSTM(128, return_sequences=True))(x)
  x = Bidirectional(LSTM(64, return_sequences=True))(x)

  avg_pool = GlobalAveragePooling1D()(x)
  max_pool = GlobalMaxPooling1D()(x)
  conc = concatenate([avg_pool, max_pool])
  conc = Dense(64, activation="relu")(conc)
  out = Dense(1, activation="sigmoid")(conc)

  model = Model(inputs=in_seq, outputs=out)
  model.compile(loss="mse", optimizer="adam", metrics=['mae', 'mape'])
  return model

model = create_model()

#model.summary()
#callback = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=2)
callback = tf.keras.callbacks.ModelCheckpoint('CNN+Bi-LSTM.hdf5', monitor='val_loss', save_best_only=True, verbose=1)

model.fit(X_train, y_train,
              batch_size=2048,
              verbose=2,
              callbacks=[callback],
              epochs=epochs,
              #shuffle=True,
              validation_data=(X_val, y_val),)

model = tf.keras.models.load_model('CNN+Bi-LSTM.hdf5')

###############################################################################
'''Calculate predictions and metrics'''

#Calculate predication for training, validation and test data
train_pred = model.predict(X_train)
val_pred = model.predict(X_val)
test_pred = model.predict(X_test)

#Print evaluation metrics for all datasets
train_eval = model.evaluate(X_train, y_train, verbose=0)
val_eval = model.evaluate(X_val, y_val, verbose=0)
test_eval = model.evaluate(X_test, y_test, verbose=0)
print(' ')
print('Evaluation metrics')
print('Training Data - Loss: {:.4f}, MAE: {:.4f}, MAPE: {:.4f}'.format(train_eval[0], train_eval[1], train_eval[2]))
print('Validation Data - Loss: {:.4f}, MAE: {:.4f}, MAPE: {:.4f}'.format(val_eval[0], val_eval[1], val_eval[2]))
print('Test Data - Loss: {:.4f}, MAE: {:.4f}, MAPE: {:.4f}'.format(test_eval[0], test_eval[1], test_eval[2]))

###############################################################################
'''Display results'''

fig = plt.figure(figsize=(15,15))
st = fig.suptitle("Moving Average - CNN + Bi-LSTM Model", fontsize=22)
st.set_y(1.02)

#Plot training data results
ax11 = fig.add_subplot(311)
ax11.plot(train_data[:, 3], label='IBM Closing Returns')
ax11.plot(train_pred, label='Predicted IBM Closing Returns')
ax11.set_title("Training Data", fontsize=18)
ax11.set_xlabel('Date')
ax11.set_ylabel('IBM Closing Returns')

#Plot validation data results
ax21 = fig.add_subplot(312)
ax21.plot(val_data[:, 3], label='IBM Closing Returns')
ax21.plot(val_pred, label='Predicted IBM Closing Returns')
ax21.set_title("Validation Data", fontsize=18)
ax21.set_xlabel('Date')
ax21.set_ylabel('IBM Closing Returns')

#Plot test data results
ax31 = fig.add_subplot(313)
ax31.plot(test_data[:, 3], label='IBM Closing Returns')
ax31.plot(test_pred, label='Predicted IBM Closing Returns')
ax31.set_title("Test Data", fontsize=18)
ax31.set_xlabel('Date')
ax31.set_ylabel('IBM Closing Returns')

plt.tight_layout()
plt.legend(loc='best')
# Out:
# 2023-08-02 15:08:25.934562: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-08-02 15:08:25.937883: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-08-02 15:08:25.939763: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-08-02 15:08:26.132997: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis' with dtype int32 and shape [1]
# 	 [[{{node gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis}}]]
# 2023-08-02 15:08:26.209900: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-08-02 15:08:26.212549: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-08-02 15:08:26.214341: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-08-02 15:08:26.518378: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-08-02 15:08:26.521650: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-08-02 15:08:26.524475: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-08-02 15:08:26.717713: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis' with dtype int32 and shape [1]
# 	 [[{{node gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis}}]]
# 2023-08-02 15:08:26.792824: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-08-02 15:08:26.795885: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-08-02 15:08:26.797732: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-08-02 15:08:27.091769: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-08-02 15:08:27.094459: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-08-02 15:08:27.096716: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-08-02 15:08:27.286052: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis' with dtype int32 and shape [1]
# 	 [[{{node gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis}}]]
# Epoch 1/5
# 2023-08-02 15:08:27.354894: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-08-02 15:08:27.358163: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-08-02 15:08:27.360428: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-08-02 15:08:29.229478: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-08-02 15:08:29.231917: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-08-02 15:08:29.233804: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-08-02 15:08:29.445902: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis' with dtype int32 and shape [1]
# 	 [[{{node gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis}}]]
# 2023-08-02 15:08:29.519296: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-08-02 15:08:29.522585: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-08-02 15:08:29.525225: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-08-02 15:08:29.809303: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-08-02 15:08:29.812389: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-08-02 15:08:29.814447: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-08-02 15:08:30.020307: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis' with dtype int32 and shape [1]
# 	 [[{{node gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis}}]]
# 2023-08-02 15:08:30.098364: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-08-02 15:08:30.100400: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-08-02 15:08:30.102254: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-08-02 15:08:30.379479: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-08-02 15:08:30.382432: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-08-02 15:08:30.384498: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-08-02 15:08:30.597027: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis' with dtype int32 and shape [1]
# 	 [[{{node gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis}}]]
# 2023-08-02 15:08:30.673695: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-08-02 15:08:30.676414: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-08-02 15:08:30.678882: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-08-02 15:08:31.427473: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis' with dtype int32 and shape [1]
# 	 [[{{node gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis}}]]
# 2023-08-02 15:08:32.030725: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis' with dtype int32 and shape [1]
# 	 [[{{node gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis}}]]
# 2023-08-02 15:08:33.411999: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis' with dtype int32 and shape [1]
# 	 [[{{node gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis}}]]
# 2023-08-02 15:08:43.172124: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-08-02 15:08:43.175322: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-08-02 15:08:43.177821: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-08-02 15:08:43.470295: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis' with dtype int32 and shape [1]
# 	 [[{{node gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis}}]]
# 2023-08-02 15:08:43.561430: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-08-02 15:08:43.563910: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-08-02 15:08:43.567556: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-08-02 15:08:43.909077: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-08-02 15:08:43.912402: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-08-02 15:08:43.914781: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-08-02 15:08:44.161816: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis' with dtype int32 and shape [1]
# 	 [[{{node gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis}}]]
# 2023-08-02 15:08:44.242367: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-08-02 15:08:44.244690: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-08-02 15:08:44.246758: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-08-02 15:08:44.550574: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-08-02 15:08:44.553452: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-08-02 15:08:44.556399: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-08-02 15:08:44.780280: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis' with dtype int32 and shape [1]
# 	 [[{{node gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis}}]]
# 2023-08-02 15:08:44.861427: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-08-02 15:08:44.864158: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-08-02 15:08:44.866149: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-08-02 15:08:45.647542: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis' with dtype int32 and shape [1]
# 	 [[{{node gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis}}]]
# 2023-08-02 15:08:46.377509: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis' with dtype int32 and shape [1]
# 	 [[{{node gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis}}]]
# 2023-08-02 15:08:47.085034: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis' with dtype int32 and shape [1]
# 	 [[{{node gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis}}]]
# 2023-08-02 15:09:45.366651: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-08-02 15:09:45.370051: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-08-02 15:09:45.372577: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-08-02 15:09:45.594183: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis' with dtype int32 and shape [1]
# 	 [[{{node gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis}}]]
# 2023-08-02 15:09:45.677226: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-08-02 15:09:45.679074: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-08-02 15:09:45.680945: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-08-02 15:09:45.977744: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-08-02 15:09:45.979841: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-08-02 15:09:45.981688: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-08-02 15:09:46.188160: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis' with dtype int32 and shape [1]
# 	 [[{{node gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis}}]]
# 2023-08-02 15:09:46.272283: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-08-02 15:09:46.274630: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-08-02 15:09:46.276812: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-08-02 15:09:46.588576: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-08-02 15:09:46.591269: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-08-02 15:09:46.593099: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-08-02 15:09:46.794777: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis' with dtype int32 and shape [1]
# 	 [[{{node gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis}}]]
# 2023-08-02 15:09:46.877276: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-08-02 15:09:46.879390: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-08-02 15:09:46.881616: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# Epoch 1: val_loss improved from inf to 0.00456, saving model to CNN+Bi-LSTM.hdf5
# 4/4 - 83s - loss: 0.0147 - mae: 0.0942 - mape: 20.0800 - val_loss: 0.0046 - val_mae: 0.0511 - val_mape: 10.5511 - 83s/epoch - 21s/step
# Epoch 2/5
#
# Epoch 2: val_loss did not improve from 0.00456
# 4/4 - 43s - loss: 0.0079 - mae: 0.0666 - mape: 14.6950 - val_loss: 0.0046 - val_mae: 0.0514 - val_mape: 10.5940 - 43s/epoch - 11s/step
# Epoch 3/5
#
# Epoch 3: val_loss improved from 0.00456 to 0.00445, saving model to CNN+Bi-LSTM.hdf5
# 4/4 - 44s - loss: 0.0073 - mae: 0.0632 - mape: 13.1708 - val_loss: 0.0044 - val_mae: 0.0496 - val_mape: 10.3854 - 44s/epoch - 11s/step
# Epoch 4/5
#
# Epoch 4: val_loss did not improve from 0.00445
# 4/4 - 43s - loss: 0.0069 - mae: 0.0612 - mape: 13.5470 - val_loss: 0.0046 - val_mae: 0.0515 - val_mape: 10.6111 - 43s/epoch - 11s/step
# Epoch 5/5
#
# Epoch 5: val_loss did not improve from 0.00445
# 4/4 - 43s - loss: 0.0066 - mae: 0.0600 - mape: 12.7727 - val_loss: 0.0045 - val_mae: 0.0497 - val_mape: 10.3930 - 43s/epoch - 11s/step
# 2023-08-02 15:12:45.571158: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-08-02 15:12:45.574257: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-08-02 15:12:45.576765: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-08-02 15:12:45.780700: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis' with dtype int32 and shape [1]
# 	 [[{{node gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis}}]]
# 2023-08-02 15:12:45.876769: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-08-02 15:12:45.878627: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-08-02 15:12:45.880432: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-08-02 15:12:46.185074: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-08-02 15:12:46.187861: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-08-02 15:12:46.190597: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-08-02 15:12:46.384829: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis' with dtype int32 and shape [1]
# 	 [[{{node gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis}}]]
# 2023-08-02 15:12:46.464413: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-08-02 15:12:46.466978: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-08-02 15:12:46.469199: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-08-02 15:12:46.769366: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-08-02 15:12:46.771376: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-08-02 15:12:46.773020: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-08-02 15:12:46.990502: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis' with dtype int32 and shape [1]
# 	 [[{{node gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis}}]]
# 2023-08-02 15:12:47.074118: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-08-02 15:12:47.075912: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-08-02 15:12:47.077571: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-08-02 15:12:49.645740: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-08-02 15:12:49.648132: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-08-02 15:12:49.649877: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-08-02 15:12:49.858701: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis' with dtype int32 and shape [1]
# 	 [[{{node gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis}}]]
# 2023-08-02 15:12:49.939482: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-08-02 15:12:49.941549: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-08-02 15:12:49.943596: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-08-02 15:12:50.229594: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-08-02 15:12:50.231661: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-08-02 15:12:50.233748: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-08-02 15:12:50.441251: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis' with dtype int32 and shape [1]
# 	 [[{{node gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis}}]]
# 2023-08-02 15:12:50.528045: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-08-02 15:12:50.529906: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-08-02 15:12:50.531562: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-08-02 15:12:50.829059: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-08-02 15:12:50.831092: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-08-02 15:12:50.832760: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-08-02 15:12:51.048379: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis' with dtype int32 and shape [1]
# 	 [[{{node gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis}}]]
# 2023-08-02 15:12:51.128377: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-08-02 15:12:51.130474: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-08-02 15:12:51.132113: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 217/217 [==============================] - 24s 89ms/step
# 24/24 [==============================] - 2s 87ms/step
# 24/24 [==============================] - 2s 86ms/step
# 2023-08-02 15:13:17.439622: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-08-02 15:13:17.443587: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-08-02 15:13:17.446716: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-08-02 15:13:17.740812: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis' with dtype int32 and shape [1]
# 	 [[{{node gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis}}]]
# 2023-08-02 15:13:17.814885: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-08-02 15:13:17.816666: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-08-02 15:13:17.818417: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-08-02 15:13:18.110631: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-08-02 15:13:18.113211: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-08-02 15:13:18.114913: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-08-02 15:13:18.336861: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis' with dtype int32 and shape [1]
# 	 [[{{node gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis}}]]
# 2023-08-02 15:13:18.421889: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-08-02 15:13:18.424578: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-08-02 15:13:18.426688: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-08-02 15:13:18.725606: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-08-02 15:13:18.727589: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-08-02 15:13:18.729429: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2023-08-02 15:13:18.938165: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis' with dtype int32 and shape [1]
# 	 [[{{node gradients/ReverseV2_grad/ReverseV2/ReverseV2/axis}}]]
# 2023-08-02 15:13:19.024657: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2023-08-02 15:13:19.027214: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2023-08-02 15:13:19.029042: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
#
# Evaluation metrics
# Training Data - Loss: 0.0074, MAE: 0.0632, MAPE: 13.2511
# Validation Data - Loss: 0.0044, MAE: 0.0496, MAPE: 10.3854
# Test Data - Loss: 0.0053, MAE: 0.0574, MAPE: 11.3374

# %% [markdown]
# ## **Conculsion 2**
#
# As expected applying a moving average to the price data smoothed the return distribution and thus lead to an improved model performance.
#
# However, when applying a moving average effect to a time series your dataset represent the real market less accurately. Subsequently, your dataset is biased towards less outliers.
#
# When investing in the stock market it is curcial that outliers are not excluded or smoothed out since outliers majorly contribute to your trading performance.
#
# Thus, any data transformations that can't be easily reverted once the predictions have been made, should be avoided.
#
# Nevertheless, seeing that a slight smoothing of the time series improved the error rates substantially for the Bi-LSTM model is a good thing to consider for future work.
#
# In conculsion, I'll be looking for other prediction indicators which will be adding to the model's performance.
#
# *Next up are financial news...*
#
#
# ##### **Moving Average Bi-LSTM**
# > Validation Data --> Loss: `0.0005`, MAE: `0.0170`, MAPE: `3.0885`
#
# > Test Data --> Loss: `0.0009`, MAE: `0.0201`, MAPE: `4.0887`
#
# ##### **Bi-LSTM**
# >Validation Data --> Loss: `0.0009`, MAE: `0.0211`, MAPE: `3.5828`
#
# >Test Data --> Loss: `0.0014`, MAE: `0.0245`, MAPE: `4.2656`
#
# ---
# ---
#
# ##### **Moving Average CNN+Bi-LSTM**
# >Validation Data --> Loss: `0.0008`, MAE: `0.0213`, MAPE: `3.8731`
#
# >Test Data --> Loss: `0.0018`, MAE: `0.0292`, MAPE: `6.2077`
#
# ##### **CNN+Bi-LSTM**
# >Validation Data --> Loss: `0.0010`, MAE: `0.0229`, MAPE: `3.8454`
#
# >Test Data --> Loss: `0.0015`, MAE: `0.0264`, MAPE: `4.5289`
