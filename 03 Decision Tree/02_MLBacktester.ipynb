# %% [markdown]
# # Backtesting - Logistic Regression
# The model will be based on the Scikit Learn LogisticRegression function. <br>
# And will be based on the features: <br>
# <ol>
#   <li>n*log return.</li>
#   <li>SMA - Moving average .</li>
#   <li>SMA_Dir - Moving average direction.</li>
#   <li>RSI - Relative Strength Index.</li>
#   <li>RSI_Dir - Relative Strength Index direction.</li>
#   <li>fastk - Stochastic RSI fastk</li>
#   <li>fastk_Dir - Stochastic RSI fastk direction</li>
#   <li>fastd - Stochastic RSI fastd</li>
#   <li>fastd_Dir - Stochastic RSI fastd direction</li>
# </ol>

# %%
import pandas as pd
import numpy as np
import yfinance as yf
from sklearn.linear_model import LogisticRegression
import matplotlib.pyplot as plt
plt.style.use("seaborn")
# Out:
# /home/mik/anaconda3/lib/python3.9/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.2
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %% [markdown]
# ## Using the MLBacktester Class

# %%
import MLBacktester as MLB

# %%
ptc = 0.00007

# %% [markdown]
# ### EURUSD

# %%
symbol = "EURUSD=X"
#symbol = "aapl"

# %%
ml = MLB.MLBacktester(symbol, '5m', '60d' ,ptc)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
ml
# Out:
# MLBacktester(symbol = EURUSD=X, start = 2023-01-30 00:05:00+00:00, end = 2023-04-21 18:55:00+01:00, tc = 7e-05)

# %%
ml.test_strategy(train_ratio = 0.7, lags = 5)
# Out:
# (0.922, -0.090851)

# %%
ml.plot_results()

# %%
ml.results
# Out:
#                               price   returns    Y      lag1      lag2  \
# Datetime
# 2023-03-28 23:00:00+01:00  1.084599  0.000108 -1.0 -0.000217  0.000000
# 2023-03-28 23:05:00+01:00  1.084599  0.000000 -1.0  0.000108 -0.000217
# 2023-03-28 23:10:00+01:00  1.085069  0.000434  1.0  0.000000  0.000108
# 2023-03-28 23:15:00+01:00  1.084716 -0.000325 -1.0  0.000434  0.000000
# 2023-03-28 23:20:00+01:00  1.084834  0.000108 -1.0 -0.000325  0.000434
# ...                             ...       ...  ...       ...       ...
# 2023-04-21 18:35:00+01:00  1.098177  0.000329  1.0 -0.000110  0.000220
# 2023-04-21 18:40:00+01:00  1.098056 -0.000110 -1.0  0.000329 -0.000110
# 2023-04-21 18:45:00+01:00  1.097936 -0.000110 -1.0 -0.000110  0.000329
# 2023-04-21 18:50:00+01:00  1.098177  0.000220 -1.0 -0.000110 -0.000110
# 2023-04-21 18:55:00+01:00  1.098418  0.000220  0.0  0.000220 -0.000110
#
#                                lag3      lag4      lag5  Ask_Dir       SMA  \
# Datetime
# 2023-03-28 23:00:00+01:00  0.000108  0.000000 -0.000108        0  1.084697
# 2023-03-28 23:05:00+01:00  0.000000  0.000108  0.000000        1  1.084677
# 2023-03-28 23:10:00+01:00 -0.000217  0.000000  0.000108        0  1.084716
# 2023-03-28 23:15:00+01:00  0.000108 -0.000217  0.000000        1  1.084707
# 2023-03-28 23:20:00+01:00  0.000000  0.000108 -0.000217        0  1.084707
# ...                             ...       ...       ...      ...       ...
# 2023-04-21 18:35:00+01:00 -0.000110 -0.000439  0.000000        0  1.098046
# 2023-04-21 18:40:00+01:00  0.000220 -0.000110 -0.000439        0  1.098067
# 2023-04-21 18:45:00+01:00 -0.000110  0.000220 -0.000110        1  1.098057
# 2023-04-21 18:50:00+01:00  0.000329 -0.000110  0.000220        1  1.098057
# 2023-04-21 18:55:00+01:00 -0.000110  0.000329 -0.000110        0  1.098057
#
#                            ...  RSI_Dir       fastk      fastd  fastk_Dir  \
# Datetime                   ...
# 2023-03-28 23:00:00+01:00  ...        0   56.243387  52.081129          0
# 2023-03-28 23:05:00+01:00  ...        1   56.243387  37.495591          1
# 2023-03-28 23:10:00+01:00  ...        0  100.000000  70.828924          0
# 2023-03-28 23:15:00+01:00  ...        1   41.391716  65.878368          1
# 2023-03-28 23:20:00+01:00  ...        0   44.242541  61.878086          0
# ...                        ...      ...         ...        ...        ...
# 2023-04-21 18:35:00+01:00  ...        0  100.000000  53.057448          0
# 2023-04-21 18:40:00+01:00  ...        0   72.747705  64.199654          0
# 2023-04-21 18:45:00+01:00  ...        1   26.489166  66.412290          1
# 2023-04-21 18:50:00+01:00  ...        1   95.123504  64.786791          1
# 2023-04-21 18:55:00+01:00  ...        0  100.000000  73.870890          0
#
#                            fastd_Dir  pred  strategy  trades  creturns  \
# Datetime
# 2023-03-28 23:00:00+01:00          0  -1.0 -0.000108     0.0  1.000108
# 2023-03-28 23:05:00+01:00          1  -1.0 -0.000000     0.0  1.000108
# 2023-03-28 23:10:00+01:00          0   1.0  0.000294     2.0  1.000542
# 2023-03-28 23:15:00+01:00          0  -1.0  0.000185     2.0  1.000217
# 2023-03-28 23:20:00+01:00          0   1.0 -0.000032     2.0  1.000325
# ...                              ...   ...       ...     ...       ...
# 2023-04-21 18:35:00+01:00          1  -1.0 -0.000329     0.0  1.012629
# 2023-04-21 18:40:00+01:00          1  -1.0  0.000110     0.0  1.012518
# 2023-04-21 18:45:00+01:00          0  -1.0  0.000110     0.0  1.012407
# 2023-04-21 18:50:00+01:00          1   0.0 -0.000070     1.0  1.012629
# 2023-04-21 18:55:00+01:00          0   1.0  0.000150     1.0  1.012852
#
#                            cstrategy
# Datetime
# 2023-03-28 23:00:00+01:00   0.999892
# 2023-03-28 23:05:00+01:00   0.999892
# 2023-03-28 23:10:00+01:00   1.000186
# 2023-03-28 23:15:00+01:00   1.000371
# 2023-03-28 23:20:00+01:00   1.000340
# ...                              ...
# 2023-04-21 18:35:00+01:00   0.921724
# 2023-04-21 18:40:00+01:00   0.921826
# 2023-04-21 18:45:00+01:00   0.921927
# 2023-04-21 18:50:00+01:00   0.921862
# 2023-04-21 18:55:00+01:00   0.922000
#
# [5080 rows x 22 columns]

# %%
ml.results.trades.value_counts()
# Out:
# 0.0    2622
# 2.0    1414
# 1.0    1044
# Name: trades, dtype: int64

# %% [markdown]
# ### EURAUD

# %%
symbol = "EURAUD"

# %%
ml = MLB.MLBacktester(symbol, "2019-01-01", "2020-08-31", ptc)
# Out:
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - EURAUD: Invalid input - interval=2019-01-01 is not supported. Valid intervals: , 2m, 5m, 15m, 30m, 60m, 90m, 1h, 1d, 5d, 1wk, 1mo, 3mo]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /home/mik/Documents/01-Algotrading/01-Python/03 ML Strategies/03 Decision Tree/02_MLBacktester.ipynb Cell 16 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/home/mik/Documents/01-Algotrading/01-Python/03%20ML%20Strategies/03%20Decision%20Tree/02_MLBacktester.ipynb#X21sZmlsZQ%3D%3D?line=0'>1</a> ml = MLB.MLBacktester(symbol, "2019-01-01", "2020-08-31", ptc)
#
# File ~/Documents/01-Algotrading/01-Python/03 ML Strategies/03 Decision Tree/MLBacktester.py:31, in MLBacktester.__init__(self, symbol, interval, period, tc)
#      29 self.model = DecisionTreeClassifier()
#      30 self.results = None
# ---> 31 self.getHistoryYfinance(symbol, interval, period)
#
# File ~/Documents/01-Algotrading/01-Python/03 ML Strategies/03 Decision Tree/MLBacktester.py:101, in MLBacktester.getHistoryYfinance(self, symbol, interval, period)
#      99 data.dropna(inplace=True)
#     100 self.data = data
# --> 101 self.start = min(data.index)
#     102 self.end = max(data.index)
#     104 return data
#
# ValueError: min() arg is an empty sequence

# %%
ml.test_strategy(train_ratio = 0.7, lags = 15)
# Out:
# (13442.546458, 13441.596714)

# %%
ml.plot_results()

# %% [markdown]
# __The optimal Number of Lags__

# %%
for lags in range(1, 21):
    print(lags, ml.test_strategy(train_ratio = 0.7, lags = lags))
# Out:
# 1 (13470.966594, 13470.016849)
# 2 (13445.51036, 13444.560615)
# 3 (13442.546458, 13441.596714)
# 4 (13442.546458, 13441.596714)
# 5 (13444.286157, 13443.336412)
# 6 (13442.828257, 13441.878513)
# 7 (13442.546458, 13441.596714)
# 8 (13442.546458, 13441.596714)
# 9 (13442.546458, 13441.596714)
# 10 (13442.546458, 13441.596714)
# 11 (13442.546458, 13441.596714)
# 12 (13442.546458, 13441.596714)
# 13 (13442.546458, 13441.596714)
# 14 (13442.546458, 13441.596714)
# 15 (13442.546458, 13441.596714)
# 16 (13442.546458, 13441.596714)
# 17 (13442.546458, 13441.596714)
# 18 (13442.546458, 13441.596714)
# 19 (13442.546458, 13441.596714)
# 20 (13470.966594, 13470.016849)

# %%
ml.results
# Out:
#                               price   returns      lag1      lag2      lag3  \
# time
# 2020-03-02 23:55:00+00:00  1.701685 -0.000482 -0.000634 -0.000364 -0.000238
# 2020-03-03 00:00:00+00:00  1.703020  0.000784 -0.000482 -0.000634 -0.000364
# 2020-03-03 00:05:00+00:00  1.703940  0.000540  0.000784 -0.000482 -0.000634
# 2020-03-03 00:10:00+00:00  1.703895 -0.000026  0.000540  0.000784 -0.000482
# 2020-03-03 00:15:00+00:00  1.703560 -0.000197 -0.000026  0.000540  0.000784
# ...                             ...       ...       ...       ...       ...
# 2020-08-30 23:35:00+00:00  1.617190 -0.000108  0.000040 -0.000043  0.000006
# 2020-08-30 23:40:00+00:00  1.616890 -0.000186 -0.000108  0.000040 -0.000043
# 2020-08-30 23:45:00+00:00  1.616870 -0.000012 -0.000186 -0.000108  0.000040
# 2020-08-30 23:50:00+00:00  1.617060  0.000118 -0.000012 -0.000186 -0.000108
# 2020-08-30 23:55:00+00:00  1.616945 -0.000071  0.000118 -0.000012 -0.000186
#
#                                lag4      lag5      lag6      lag7      lag8  \
# time
# 2020-03-02 23:55:00+00:00  0.000050  0.000176 -0.000047  0.000065  0.000285
# 2020-03-03 00:00:00+00:00 -0.000238  0.000050  0.000176 -0.000047  0.000065
# 2020-03-03 00:05:00+00:00 -0.000364 -0.000238  0.000050  0.000176 -0.000047
# 2020-03-03 00:10:00+00:00 -0.000634 -0.000364 -0.000238  0.000050  0.000176
# 2020-03-03 00:15:00+00:00 -0.000482 -0.000634 -0.000364 -0.000238  0.000050
# ...                             ...       ...       ...       ...       ...
# 2020-08-30 23:35:00+00:00  0.000012  0.000121  0.000099 -0.000083  0.000195
# 2020-08-30 23:40:00+00:00  0.000006  0.000012  0.000121  0.000099 -0.000083
# 2020-08-30 23:45:00+00:00 -0.000043  0.000006  0.000012  0.000121  0.000099
# 2020-08-30 23:50:00+00:00  0.000040 -0.000043  0.000006  0.000012  0.000121
# 2020-08-30 23:55:00+00:00 -0.000108  0.000040 -0.000043  0.000006  0.000012
#
#                            ...  RSI_Dir       fastk         fastd  fastk_Dir  \
# time                       ...
# 2020-03-02 23:55:00+00:00  ...        1    0.000000  0.000000e+00          1
# 2020-03-03 00:00:00+00:00  ...        1   64.255652  2.141855e+01          1
# 2020-03-03 00:05:00+00:00  ...        0  100.000000  5.475188e+01          0
# 2020-03-03 00:10:00+00:00  ...        0   98.217867  8.749117e+01          0
# 2020-03-03 00:15:00+00:00  ...        0   84.612103  9.427666e+01          0
# ...                        ...      ...         ...           ...        ...
# 2020-08-30 23:35:00+00:00  ...        0    0.000000  4.564589e+01          0
# 2020-08-30 23:40:00+00:00  ...        0    0.000000  2.681568e+01          0
# 2020-08-30 23:45:00+00:00  ...        1    0.000000  1.468455e-13          1
# 2020-08-30 23:50:00+00:00  ...        0   41.525249  1.384175e+01          0
# 2020-08-30 23:55:00+00:00  ...        0   29.145529  2.355693e+01          0
#
#                            fastd_Dir  pred  strategy  trades  creturns  \
# time
# 2020-03-02 23:55:00+00:00          1  -1.0  0.000482     0.0  0.999518
# 2020-03-03 00:00:00+00:00          1   1.0  0.000644     2.0  1.000302
# 2020-03-03 00:05:00+00:00          1   1.0  0.000540     0.0  1.000843
# 2020-03-03 00:10:00+00:00          1   1.0 -0.000026     0.0  1.000816
# 2020-03-03 00:15:00+00:00          0  -1.0  0.000057     2.0  1.000620
# ...                              ...   ...       ...     ...       ...
# 2020-08-30 23:35:00+00:00          0  -1.0 -0.000032     2.0  0.949889
# 2020-08-30 23:40:00+00:00          0  -1.0  0.000186     0.0  0.949712
# 2020-08-30 23:45:00+00:00          1  -1.0  0.000012     0.0  0.949701
# 2020-08-30 23:50:00+00:00          1   1.0 -0.000022     2.0  0.949812
# 2020-08-30 23:55:00+00:00          0   1.0 -0.000071     0.0  0.949745
#
#                               cstrategy
# time
# 2020-03-02 23:55:00+00:00      1.000482
# 2020-03-03 00:00:00+00:00      1.001127
# 2020-03-03 00:05:00+00:00      1.001667
# 2020-03-03 00:10:00+00:00      1.001641
# 2020-03-03 00:15:00+00:00      1.001698
# ...                                 ...
# 2020-08-30 23:35:00+00:00  13469.561935
# 2020-08-30 23:40:00+00:00  13472.061096
# 2020-08-30 23:45:00+00:00  13472.227739
# 2020-08-30 23:50:00+00:00  13471.924673
# 2020-08-30 23:55:00+00:00  13470.966594
#
# [37104 rows x 36 columns]

# %%
hits = np.sign(ml.results.returns * ml.results.pred).value_counts()
hits
# Out:
#  1.0    32027
# -1.0     4936
#  0.0      141
# dtype: int64

# %%
hit_ratio = hits[1.0] / sum(hits)
hit_ratio
# Out:
# 0.8631683915480811
